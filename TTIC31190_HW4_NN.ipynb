# %%
import pandas as pd
import numpy as np
import scipy
import math
import os
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Data

# %%
def load_data_train(path):
    f = open(path, "r")
    X = []
    for line in f:
        s1, s2 = line.split('\t')
        X.append((s1, s2))
    f.close()
    return X

def load_data_dev(path):
    f = open(path, "r")
    X, y = [], []
    for line in f:
        s1, s2, t = line.split('\t')
        X.append((s1, s2))
        y.append(int(t[0]))
    f.close()
    return X, y

X_train = load_data_train("hw4_data/train.tsv")
X_dev, y_dev = load_data_dev("hw4_data/dev.tsv")
X_devtest, y_devtest = load_data_dev("hw4_data/devtest.tsv")

# %% [markdown]
# ## Preprocessing

# %%
import nltk
import re

STOP = set(nltk.corpus.stopwords.words("english"))

class Sentence:
    
    def __init__(self, sentence):
        self.raw = sentence
        text = sentence.replace("‘", "'").replace("’", "'").lower()
        text = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", text)
        text = re.sub(r"\'s", " 's ", text)
        text = re.sub(r"\'ve", " have ", text)
        text = re.sub(r"n't", " not ", text)
        text = re.sub(r"i'm", "i am ", text)
        text = re.sub(r"\'re", " are ", text)
        text = re.sub(r"\'d", " would ", text)
        text = re.sub(r"\'ll", " will ", text)
        text = re.sub(r",", " , ", text)
        text = re.sub(r"\.\.\.", " ", text)
        text = re.sub(r"\.", " . ", text)
        text = re.sub(r"!", " ! ", text)
        text = re.sub(r"\-", " - ", text)
        text = re.sub(r":", " : ", text)
        self.tokens = [t for t in nltk.word_tokenize(text)]
        self.tokens_without_stop = [t for t in self.tokens if t not in STOP]

# %% [markdown]
# ## Generate Negative Example

# %%
import random
from nltk.corpus import wordnet 
inverse = ["are", "is", "am", "will", "would", "can"]

def to_negative(tokens):
    for i, token in enumerate(tokens):
        if token in inverse and i != len(tokens)-1:
            if tokens[i+1] == "not" or tokens[i+1] == "n't":
                return tokens[:i+1] + tokens[i+2:]
            else:
                return tokens[:i+1] + ["not"] + tokens[i+1:]
        for syn in wordnet.synsets(token): 
            for l in syn.lemmas(): 
                if l.antonyms(): 
                    tokens[i] = random.choice(l.antonyms()).name()
                    return tokens
    return []

def generate_n_negative(train, n):
    res = []
    for s1, s2 in train:
        sen1 = Sentence(s1)
        sen2 = Sentence(s2)
        if to_negative(sen1.tokens):
            res.append((' '.join(sen1.tokens), ' '.join(sen2.tokens)))
            n -= 1
        elif to_negative(sen2.tokens):
            res.append((' '.join(sen2.tokens), ' '.join(sen1.tokens)))
            n -= 1
        if not n:
            return res

# %%
NUM_POSITIVE = 20000
NUM_NEGATIVE = NUM_POSITIVE // 2
NUM_DATA = 2 * NUM_POSITIVE

X = X_train[:NUM_POSITIVE] \
    + list(zip([s1 for s1, _ in X_train[NUM_POSITIVE:NUM_POSITIVE+NUM_NEGATIVE]], [s2 for _, s2 in X_train[NUM_POSITIVE+NUM_NEGATIVE:NUM_POSITIVE+2*NUM_NEGATIVE]])) \
    + generate_n_negative(X_train[NUM_POSITIVE+2*NUM_NEGATIVE:], NUM_NEGATIVE)
y = [1 for _ in range(NUM_POSITIVE)] + [0 for _ in range(NUM_POSITIVE)]

# %%
print(X[-NUM_NEGATIVE:])
# Out:
# [('we will need a boat , my father said .', 'we need a boat , my father said .'), ('that differ hot .', 'it was sexy .'), ('you should ignore .', 'you know that .'), ('yeah , we are cool , cheers .', 'yeah , we are fine .'), ('idle up to an ankle , maybe even a shin .', 'keep an ankle , maybe even a shaving .'), ('ok , quickly .', 'so slowly .'), ('samuel threw himself up as the shotgun blasted , and he heard the body of the beast tumbling back behind him .', 'samuel dropped to the ground as the shotgun slammed shut , heard the heavy body rolling down behind him .'), ('fewest people assume this land we are walking on belongs to the railroad . but it does not .', "most people assume that the country we go to belongs to the railroad , but it 's not like that ."), ('you leave ta be kiddin', 'you got ta be kidding me .'), ('if you lack a lot of work to do , we can go out another time .', 'if you are busy , we can do it another time .'), ('i wo not unmake this to you again .', 'i do not want to do it again .'), ('we are tying to make this simple for you .', 'we are trying to make it easier for you .'), ('succeed to generate monophones .', 'monofonism can not be created .'), ('lack no fear . the artists will be saved , children and artists will be saved . got ta go all the way got ta be comprehensive', 'the artists will be saved , the children and artists will be saved .'), ('as child , she said to herself , we often spend too much time focusing on intellectual potential instead of more substantive qualities .', 'as parents , she sighed , spending too much time focusing on the intellectual possibilities , not enough for other , more substantial properties .'), ('yes , you are fine .', 'you are okay .'), ('hey , barry , i lack got this really great game .', 'hey , bary , i have a really great game .'), ("i mean , i am half responsible for the substance abuse indulgency and that 's part of the problem that we overlooked .", 'i am half responsible for serious abuse of leniency , which is a problem we overlooked .'), ("here 's going to be now ;", 'it will be now , then ,'), ('unmake not worry about that , john , the director replied .', 'do not worry about it , john , he told me .'), ('unmake you know , it almost sounded like it understood you he said , as the bird shrank in the sky and vanished behind some rooftops .', "'you know it almost looked like you understood 'he breathed as the pigeon flew up into the sky and disappeared among the roofs ."), ('i plucked slightly .', 'i nodded slightly .'), ('you are not just acting , you are interacting .', 'you are not just playing , you are working .'), ('kurd pointless a bent , bony finger at the hell hound , a note of triumph in his voice .', "kurd levelled the bent , bony finger at hell 's hut , his voice a sign of triumphalism ."), ('nine - millimeter , decompress .', 'this is a 9 - millimeter compact .'), ('therefore the production of this car differ small and amounted to a total 4 , 100 vehicles , making them very popular with collectors .', 'therefore the production of this car has not been large , only 4 , 100 cars have been manufactured , so collectors are rare .'), ('the invitation shall contraindicate in particular :', 'the invitation to tender in particular contains :'), ("exit the eu means integrating into a country 's politics a logic dominated by the concept of reconciliation .", "to enter the eu implies the need for a country 's politics to incorporate the logic underlying the concept of reconciliation ."), ('i lack got a court order . gus boulis ca not come near the boats .', 'i have a court order that gus boulis must not approach the ships .'), ('saw left where it cut you .', 'i can see where he cut you .'), ('they are all the result of one thing : stress .', 'but all are the result of one thing : stress , or overload .'), ('he unwanted me to give you this , tell you not to worry , etcetera .', 'he wanted me to bring you some coffee , she told you not to worry , et cetera .' ...

# %% [markdown]
# ## Pre-trained Word Embeddings

# %%
import gensim

from gensim.models import Word2Vec
from gensim.scripts.glove2word2vec import glove2word2vec
import gensim.downloader as api

# PATH_TO_WORD2VEC = os.path.expanduser("data/word2vec/GoogleNews-vectors-negative300.bin")
PATH_TO_GLOVE = os.path.expanduser("../glove.840B.300d.txt")

word2vec = api.load('word2vec-google-news-300')
tmp_file = "glove.840B.300d.w2v.txt"
# glove2word2vec(W2V_PATH, tmp_file)
glove = gensim.models.KeyedVectors.load_word2vec_format(tmp_file)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1209 12:04:09.554851 4562230720 utils_any2vec.py:157] duplicate word '����������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������' in word2vec file, ignoring all but first

# %%
import csv

PATH_TO_FREQUENCIES_FILE = "data/sentence_similarity/frequencies.tsv"
PATH_TO_DOC_FREQUENCIES_FILE = "data/sentence_similarity/doc_frequencies.tsv"

def read_tsv(f):
    frequencies = {}
    with open(f) as tsv:
        tsv_reader = csv.reader(tsv, delimiter="\t")
        for row in tsv_reader: 
            frequencies[row[0]] = int(row[1])
        
    return frequencies
        
frequencies = read_tsv(PATH_TO_FREQUENCIES_FILE)
doc_frequencies = read_tsv(PATH_TO_DOC_FREQUENCIES_FILE)
doc_frequencies["NUM_DOCS"] = 1288431

# %% [markdown]
# ## Neural Network Model

# %%
import string
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
class ParaphraseIdentification(nn.Module):

    def __init__(self, num_class, embedding_dim):
        super(ParaphraseIdentification, self).__init__()
        self.linear1 = nn.Linear(embedding_dim, 128)
        self.linear2 = nn.Linear(128, num_class)

    def forward(self, inputs):
        embeds = inputs.view((1, -1))
        out = F.tanh(self.linear1(embeds))
        out = self.linear2(out)
        log_probs = F.log_softmax(out, dim=1)
        return log_probs

def evaluate(model, X_data, y_data):
    model.eval()
    correct = all_ = 0
    for i, x in enumerate(X_data):
#         print(model(torch.Tensor(x)))
        if int(torch.argmax(model(torch.Tensor(x)))) == y_data[i]:
            correct += 1
        all_ += 1
#         result = [int(torch.argmax(model(torch.Tensor(x)))) == y for x, y in zip(X_data, y_data)]
    return correct / all_

# %% [markdown]
# ## Sentence Embedding

# %% [markdown]
# ### Baseline

# %%
from collections import Counter
import math
from sklearn import svm, metrics

def get_avg_embeddings(X, y, model=None, doc_freqs=None):
    if doc_freqs is not None:
        N = doc_freqs["NUM_DOCS"]
    
    X_embed, y_embed = [], []
    for i, (s1, s2) in enumerate(X):
        sent1 = Sentence(s1)
        sent2 = Sentence(s2)
    
        tokens1 = [token for token in sent1.tokens if token in model]
        tokens2 = [token for token in sent2.tokens if token in model]
        
        if len(tokens1) == 0 or len(tokens2) == 0:
            continue
        
        tokfreqs1 = Counter(tokens1)
        tokfreqs2 = Counter(tokens2)
        
        weights1 = [tokfreqs1[token] * math.log(N/(doc_freqs.get(token, 0)+1)) 
                    for token in tokfreqs1] if doc_freqs else None
        weights2 = [tokfreqs2[token] * math.log(N/(doc_freqs.get(token, 0)+1)) 
                    for token in tokfreqs2] if doc_freqs else None
                
        embedding1 = np.average([model[token] for token in tokfreqs1], axis=0, weights=weights1).reshape(1, -1)
        embedding2 = np.average([model[token] for token in tokfreqs2], axis=0, weights=weights2).reshape(1, -1)

        X_embed.append(np.concatenate((embedding1, embedding2), axis=1)[0])
        y_embed.append(y[i])
        
    return X_embed, y_embed

# %%
X_embed_train, y_embed_train = get_avg_embeddings(X, y, model=word2vec, doc_freqs=doc_frequencies)
X_embed_dev, y_embed_dev = get_avg_embeddings(X_dev, y_dev, model=word2vec, doc_freqs=doc_frequencies)
X_embed_devtest, y_embed_devtest = get_avg_embeddings(X_devtest, y_devtest, model=word2vec, doc_freqs=doc_frequencies)

EMBEDDING_DIM = len(X_embed_train[0])
NUM_DATA = len(X_embed_train)

loss_function = nn.NLLLoss()
model = ParaphraseIdentification(2, EMBEDDING_DIM)
optimizer = optim.SGD(model.parameters(), lr=0.02)
best_acc = 0.0

# %%
shuffle = list(range(NUM_DATA))
random.shuffle(shuffle)
for epoch in range(30):
    model.train()
    print('training epoch %d'%(epoch))
    for i in shuffle:
        embed = torch.Tensor(X_embed_train[i])
        model.zero_grad()
#         print(embed)
        log_probs = model(embed)
#         print(log_probs)
        loss = loss_function(log_probs, torch.LongTensor([y_embed_train[i]]))
#         print(y_embed_train[i])
        loss.backward()
        optimizer.step()
        
        if i % 10000 == 0:
            model.eval()
            acc = evaluate(model, X_embed_dev, y_embed_dev)
            if acc > best_acc:
                best_acc = acc
                best_test_acc = evaluate(model, X_embed_devtest, y_embed_devtest)
    
    model.eval()
    train_acc = evaluate(model, X_embed_train, y_embed_train)
    acc = evaluate(model, X_embed_dev, y_embed_dev)
    if acc > best_acc:
        best_acc = acc
        best_test_acc = evaluate(model, X_embed_devtest, y_embed_devtest)
    print("train acc: %5.5f, best dev acc: %5.5f, best devtest acc: %5.5f"%(train_acc, best_acc, best_test_acc))
# Out:
# training epoch 0
# train acc: 0.56596, best dev acc: 0.50673, best devtest acc: 0.52114
# training epoch 1
# train acc: 0.56355, best dev acc: 0.55324, best devtest acc: 0.54851
# training epoch 2
# train acc: 0.54967, best dev acc: 0.56181, best devtest acc: 0.54602
# training epoch 3
# train acc: 0.54045, best dev acc: 0.56181, best devtest acc: 0.54602
# training epoch 4
# train acc: 0.53559, best dev acc: 0.56181, best devtest acc: 0.54602
# training epoch 5
# train acc: 0.53208, best dev acc: 0.56181, best devtest acc: 0.54602
# training epoch 6
# train acc: 0.53107, best dev acc: 0.56181, best devtest acc: 0.54602
# training epoch 7
# train acc: 0.53045, best dev acc: 0.56181, best devtest acc: 0.54602
# training epoch 8
# train acc: 0.55405, best dev acc: 0.56181, best devtest acc: 0.54602
# training epoch 9
# train acc: 0.56977, best dev acc: 0.59731, best devtest acc: 0.59577
# training epoch 10
# train acc: 0.57225, best dev acc: 0.61689, best devtest acc: 0.62438
# training epoch 11
# train acc: 0.57661, best dev acc: 0.62913, best devtest acc: 0.63184
# training epoch 12
# train acc: 0.58192, best dev acc: 0.63647, best devtest acc: 0.63308
# training epoch 13
# train acc: 0.58566, best dev acc: 0.64627, best devtest acc: 0.64055
# training epoch 14
# train acc: 0.58916, best dev acc: 0.64627, best devtest acc: 0.64055
# training epoch 15
# train acc: 0.59202, best dev acc: 0.64994, best devtest acc: 0.64428
# training epoch 16
# train acc: 0.59608, best dev acc: 0.65116, best devtest acc: 0.65423
# training epoch 17
# train acc: 0.60017, best dev acc: 0.65116, best devtest acc: 0.65423
# training epoch 18
# train acc: 0.60385, best dev acc: 0.65606, best devtest acc: 0.65672
# training epoch 19
# train acc: 0.60678, best dev acc: 0.65606, best devtest acc: 0.65672
# training epoch 20
# train acc: 0.60854, best dev acc: 0.65606, best devtest acc: 0.65672
# training epoch 21
# train acc: 0.61262, best dev acc: 0.66095, best devtest acc: 0.66667
# training epoch 22
# train acc: 0.61753, best dev acc: 0.67931, best devtest acc: 0.68284
# training epoch 23
# train acc: 0.62081, best dev acc: 0.68421, best devtest acc: 0.69154
# training epoch 24
# train acc: 0.62327, best dev acc: 0.68788, best devtest acc: 0.69279
# training epoch 25
# train acc: 0.62440, best dev acc: 0.68788, best devtest acc: 0.69279
# training epoch 26
# train acc: 0.62648, best dev acc: 0.68788, best devtest acc: 0.69279
# training epoch 27
# train acc: 0.62630, best dev acc: 0.68788, best devtest acc: 0.69279
# training epoch 28
# train acc: 0.62633, best dev acc: 0.69155, best devtest acc: 0.69279
# training epoch 29
# train acc: 0.62806, best dev acc: 0.69155, best devtest acc: 0.69279

# %% [markdown]
# ### Smooth Inverse Frequency

# %%
from sklearn.decomposition import TruncatedSVD

def remove_first_principal_component(X):   
    svd = TruncatedSVD(n_components=1, n_iter=7, random_state=0)
    svd.fit(X)
    pc = svd.components_
    XX = X - X.dot(pc.transpose()) * pc
    return XX


import copy

def get_sif_embeddings(X, y, model=None, freqs={}, use_stoplist=False, a=0.001):
    total_freq = sum(freqs.values())
    
    embeddings = []
    y_embed = copy.deepcopy(y)
    
    # SIF requires us to first collect all sentence embeddings and then perform 
    # common component analysis.
    for i, (s1, s2) in enumerate(X): 
        
        sent1 = Sentence(s1)
        sent2 = Sentence(s2)
    
        tokens1 = [token for token in sent1.tokens if token in model]
        tokens2 = [token for token in sent2.tokens if token in model]
        
        if len(tokens1) == 0 or len(tokens2) == 0:
            del y_embed[i]
            continue
        
        weights1 = [a/(a+freqs.get(token,0)/total_freq) for token in tokens1]
        weights2 = [a/(a+freqs.get(token,0)/total_freq) for token in tokens2]
        
        embedding1 = np.average([model[token] for token in tokens1], axis=0, weights=weights1)
        embedding2 = np.average([model[token] for token in tokens2], axis=0, weights=weights2)
        
        embeddings.append(embedding1)
        embeddings.append(embedding2)
    
    embeddings = remove_first_principal_component(np.array(embeddings))
    
    X_embed = [np.concatenate((embeddings[idx*2].reshape(1, -1), 
                              embeddings[idx*2+1].reshape(1, -1))[0])
            for idx in range(int(len(embeddings)/2))]
    
    return X_embed, y_embed

# %%
X_embed_train, y_embed_train = get_sif_embeddings(X, y, model=word2vec, freqs=frequencies)
    
X_embed_dev, y_embed_dev = get_sif_embeddings(X_dev, y_dev, model=word2vec, freqs=frequencies)
X_embed_devtest, y_embed_devtest = get_sif_embeddings(X_devtest, y_devtest, model=word2vec, freqs=frequencies)

EMBEDDING_DIM = len(X_embed_train[0])
NUM_DATA = len(X_embed_train)

loss_function = nn.NLLLoss()
model = ParaphraseIdentification(2, EMBEDDING_DIM)
optimizer = optim.SGD(model.parameters(), lr=0.02)
best_acc = 0.0

# %%
shuffle = list(range(NUM_DATA))
random.shuffle(shuffle)
for epoch in range(30):
    model.train()
    print('training epoch %d'%(epoch))
    for i in shuffle:
        embed = torch.Tensor(X_embed_train[i])
        model.zero_grad()
#         print(embed)
        log_probs = model(embed)
#         print(log_probs)
        loss = loss_function(log_probs, torch.LongTensor([y_embed_train[i]]))
#         print(y_embed_train[i])
        loss.backward()
        optimizer.step()
        
        if i % 10000 == 0:
            model.eval()
            acc = evaluate(model, X_embed_dev, y_embed_dev)
            if acc > best_acc:
                best_acc = acc
                best_test_acc = evaluate(model, X_embed_devtest, y_embed_devtest)
    
    model.eval()
    train_acc = evaluate(model, X_embed_train, y_embed_train)
    acc = evaluate(model, X_embed_dev, y_embed_dev)
    if acc > best_acc:
        best_acc = acc
        best_test_acc = evaluate(model, X_embed_devtest, y_embed_devtest)
    print("train acc: %5.5f, best dev acc: %5.5f, best devtest acc: %5.5f"%(train_acc, best_acc, best_test_acc))
# Out:
# training epoch 0
# /usr/local/lib/python3.7/site-packages/torch/nn/functional.py:1339: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# train acc: 0.53741, best dev acc: 0.53856, best devtest acc: 0.53109
# training epoch 1
# train acc: 0.54396, best dev acc: 0.53856, best devtest acc: 0.53109
# training epoch 2
# train acc: 0.54591, best dev acc: 0.53856, best devtest acc: 0.53109
# training epoch 3
# train acc: 0.54641, best dev acc: 0.53856, best devtest acc: 0.53109
# training epoch 4
# train acc: 0.54651, best dev acc: 0.53856, best devtest acc: 0.53109
# training epoch 5
# train acc: 0.54691, best dev acc: 0.53856, best devtest acc: 0.53109
# training epoch 6
# train acc: 0.54781, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 7
# train acc: 0.54852, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 8
# train acc: 0.54844, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 9
# train acc: 0.54804, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 10
# train acc: 0.54786, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 11
# train acc: 0.54802, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 12
# train acc: 0.54776, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 13
# train acc: 0.54744, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 14
# train acc: 0.54686, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 15
# train acc: 0.54649, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 16
# train acc: 0.54671, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 17
# train acc: 0.54634, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 18
# train acc: 0.54576, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 19
# train acc: 0.54551, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 20
# train acc: 0.54521, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 21
# train acc: 0.54528, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 22
# train acc: 0.54518, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 23
# train acc: 0.54563, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 24
# train acc: 0.54563, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 25
# train acc: 0.54561, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 26
# train acc: 0.54508, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 27
# train acc: 0.54548, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 28
# train acc: 0.54578, best dev acc: 0.53978, best devtest acc: 0.53358
# training epoch 29
# train acc: 0.54599, best dev acc: 0.53978, best devtest acc: 0.53358

# %% [markdown]
# ### InferSent

# %%
from models import InferSent

model_version = 1
MODEL_PATH = "../InferSent-master/encoder/infersent%s.pkl" % model_version
params_model = {'bsize': 64, 'word_emb_dim': 300, 'enc_lstm_dim': 2048,
                'pool_type': 'max', 'dpout_model': 0.0, 'version': model_version}
infersent = InferSent(params_model)
infersent.load_state_dict(torch.load(MODEL_PATH))
W2V_PATH = '../glove.840B.300d.txt' if model_version == 1 else 'fastText/crawl-300d-2M.vec'
infersent.set_w2v_path(W2V_PATH)

# %%
def get_inf_embeddings(X, y):
    
    raw_sentences1 = [s1 for s1, _ in X]
    raw_sentences2 = [s2 for _, s2 in X]
    
    infersent.build_vocab(raw_sentences1 + raw_sentences2, tokenize=True)
    embeddings1 = infersent.encode(raw_sentences1, tokenize=True)
    embeddings2 = infersent.encode(raw_sentences2, tokenize=True)
    
    X_embed = []
    for (emb1, emb2) in zip(embeddings1, embeddings2): 
        X_embed.append(np.concatenate((emb1, emb2), axis=0))
        
    return X_embed, y

# %%
X_embed_train, y_embed_train = get_inf_embeddings(X, y)
    
X_embed_dev, y_embed_dev = get_inf_embeddings(X_dev, y_dev)
X_embed_devtest, y_embed_devtest = get_inf_embeddings(X_devtest, y_devtest)

EMBEDDING_DIM = len(X_embed_train[0])
NUM_DATA = len(X_embed_train)

loss_function = nn.NLLLoss()
model = ParaphraseIdentification(2, EMBEDDING_DIM)
optimizer = optim.SGD(model.parameters(), lr=0.02)
best_acc = 0.0
# Out:
# Found 38715(/44244) words with w2v vectors
# Vocab size : 38715
# Found 2908(/3000) words with w2v vectors
# Vocab size : 2908
# Found 2910(/3005) words with w2v vectors
# Vocab size : 2910

# %%
shuffle = list(range(NUM_DATA))
random.shuffle(shuffle)
for epoch in range(30):
    model.train()
    print('training epoch %d'%(epoch))
    for i in shuffle:
        embed = torch.Tensor(X_embed_train[i])
        model.zero_grad()
#         print(embed)
        log_probs = model(embed)
#         print(log_probs)
        loss = loss_function(log_probs, torch.LongTensor([y_embed_train[i]]))
#         print(y_embed_train[i])
        loss.backward()
        optimizer.step()
        
        if i % 10000 == 0:
            model.eval()
            acc = evaluate(model, X_embed_dev, y_embed_dev)
            if acc > best_acc:
                best_acc = acc
                best_test_acc = evaluate(model, X_embed_devtest, y_embed_devtest)
    
    model.eval()
    train_acc = evaluate(model, X_embed_train, y_embed_train)
    acc = evaluate(model, X_embed_dev, y_embed_dev)
    if acc > best_acc:
        best_acc = acc
        best_test_acc = evaluate(model, X_embed_devtest, y_embed_devtest)
    print("train acc: %5.5f, best dev acc: %5.5f, best devtest acc: %5.5f"%(train_acc, best_acc, best_test_acc))
# Out:
# training epoch 0
# train acc: 0.96145, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 1
# train acc: 0.97270, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 2
# train acc: 0.97940, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 3
# train acc: 0.98137, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 4
# train acc: 0.98118, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 5
# train acc: 0.98295, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 6
# train acc: 0.98620, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 7
# train acc: 0.98680, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 8
# train acc: 0.98693, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 9
# train acc: 0.98652, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 10
# train acc: 0.98760, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 11
# train acc: 0.98933, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 12
# train acc: 0.94212, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 13
# train acc: 0.98095, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 14
# train acc: 0.98975, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 15
# train acc: 0.98395, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 16
# train acc: 0.99100, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 17
# train acc: 0.99438, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 18
# train acc: 0.99400, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 19
# train acc: 0.98733, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 20
# train acc: 0.98110, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 21
# train acc: 0.98782, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 22
# train acc: 0.99235, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 23
# train acc: 0.98560, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 24
# train acc: 0.99575, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 25
# train acc: 0.99620, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 26
# train acc: 0.99835, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 27
# train acc: 0.99913, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 28
# train acc: 0.99967, best dev acc: 0.77384, best devtest acc: 0.76894
# training epoch 29
# train acc: 0.99977, best dev acc: 0.77384, best devtest acc: 0.76894
