# %%
import pandas as pd
import numpy as np
import scipy
import math
import os
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Data

# %%
def load_data_train(path):
    f = open(path, "r")
    X = []
    for line in f:
        s1, s2 = line.split('\t')
        X.append((s1, s2))
    f.close()
    return X

def load_data_dev(path):
    f = open(path, "r")
    X, y = [], []
    for line in f:
        s1, s2, t = line.split('\t')
        X.append((s1, s2))
        y.append(int(t[0]))
    f.close()
    return X, y

X_train = load_data_train("hw4_data/train.tsv")
X_dev, y_dev = load_data_dev("hw4_data/dev.tsv")
X_devtest, y_devtest = load_data_dev("hw4_data/devtest.tsv")

# %%
X_dev[50:]
# Out:
# [('What, what happened?', 'what, what, what...?'),
#  ('This man is a crook.', 'it means the man is not a man.'),
#  ('Do you wanna know what I would write?', 'you wanna die too?'),
#  ('A bear.', 'bear.'),
#  ('What do you think Neal wants?', 'do you think what I think you think?'),
#  ("What's the matter with me, Nancy?", "what's the matter with you?"),
#  ('"Do we have any idea what that big freighter is doing riding in orbit so close to the space station?"',
#   '"do we have any idea what makes a large cargo ship in orbit so close to the space station?"'),
#  ("So I see. There's a great band at El Chico, in the Village.",
#   "there's a great band in the Village, in El Chico."),
#  ('Already cuffed! about another mile on this road, turn left on Cabrillo.',
#   'one more mile on this road and turn left on Cabrillo.'),
#  ('Hummin smiled slightly.', 'hummin smiled weakly.'),
#  ('Why do women always do that?', 'why do women keep doing this?'),
#  ("I'm glad you're here to tell us these things.", "I'm glad to have you."),
#  ('"Are you expecting Miss Fairfax here soon?"', 'are you expecting someone?'),
#  ('I just got it.', 'I got it, I got it.'),
#  ('"Wait . . . wait till Osaka."', 'wait, wait.'),
#  ("That's far enough.", "it's not that far."),
#  ("Captain's Log, stardate 1672.1.", "captain's log, stardate 43125.8."),
#  ("I'm sorry, that was... that was dumb.", 'that was... that was great.'),
#  ("I'm telling you, I'm warm.", "I'm telling you, I..."),
#  ('You laughed about that until you threw up.',
#   'you were laughing about it until you threw up.'),
#  ("I'm gonna kill every one of you.", "I'll kill you all."),
#  ('"Never mind," said Miles.', '"I never said that," I said.'),
#  ('Yes, he was telling the truth.', 'yes, he spoke the truth.'),
#  ('You broke it.', 'when you broke in.'),
#  ('"What\'re you doing?" Garraty repeated patiently.',
#   '"what are you doing?" Garraty said patiently.'),
#  ('I know you do, Brenda. I know you do.', '"I know, I know.'),
#  ('Nabídka náhradních dílů, vý Jiří Šperlík - ANTIQUA - STAROŽITNÍK Obchod se starožitnostmi.',
#   'Prodej a servis motocyklů a příslušenství.'),
#  ('Hey, well... good-bye, Mole.', 'look, all right... bye-bye, Mole.'),
#  ('There was inflation and millions of refugees.',
#   'millions and millions of souls.'),
#  ("It's only a tree", "it's not a tree."),
#  ('During the overture... ...she said to me, "I want to pee."',
#   'during the prelude...... she told me, "I have to pee."'),
#  ('Take that thing with you.', 'and take this thing with you.'),
#  ("'I'll tell you where to find them if you promise not to kill anybody.'",
#   "if you still want to kill yourself, I'll help you."),
#  ("I'll host the first one, we'il start with Emma, at my place.",
#   "I'll host first, starting with Emma at my house."),
#  ('Come on. Fuck, come on.', 'come on, come on!'),
#  ('Babies, come on.', 'come on, come on. Come on.'),
#  ('I got it. I win.', 'I got it, I got it.'),
#  ('He jerked up his chin and smiled thinly.', 'he jerked his head.'),
#  ('Pipette 625 mg', 'pipette (625 mg)'),
#  ('They got really drunk and these sailors took them out.',
#   'they got drunk, and the sailors went out with them.'),
#  ('My apartment is right there, rather I should say, our apartments.',
#   'my apartment is right here, or rather - our apartments are here.'),
#  ('Hi. Nice to meet you.', 'hello, nice to meet you.'),
#  ("Don't tell me you can't read, Driss!", "don't tell me you don't read!"),
#  ('I like the way you beg, boy.', 'seriously, I really like you.'),
#  ("It's good to see you, Nolan.", 'nice to see you, Nolan.'),
#  ('Your freedom.', 'freedom.'),
#  ('No, thank you.', '"thank you, thank you."'),
#  ('I just want you to ask him... Did he know that I loved him?',
#   'I just want you to ask him...... if he knows I loved him.'),
#  ("She's not gonna come back every morning and walk a dog,",
#   "he's not going to come here every morning and walk the dog."),
#  ("I mean, admittedly, you're my sister, and I love you, so I'm biased.",
#   'you love, you love, you love!'),
#  ("What's your name, son?", "hey, what's your name?"),
#  ('It said he was the greatest criminal lawyer, the greatest criminal.',
#   'criminal... criminal.'),
#  ("I've got an album to finish.", 'I have to make an album.'),
#  ('Motherfucker, wake up!', 'wake up, wake up!'),
#  ('Have I got some news for you.', 'good news and bad news'),
#  ('The King Beyond the Gate!', 'the king at the gate!'),
#  ('( 102 ) OJ L 30, 31.1.2009, p.', 'OJ L 102 7.4.2004, p.'),
#  ("'A troop of twenty Iron Wolves travelled with Meria.",
#   "'There was a section of twenty Iron Wolves with Meria."),
#  ('Rapporteur: Alexandra Thein (A7-0185/2012)',
#   'rapporteur: Alexandra Thein (A7-0185 / 2012)'),
#  ("I'm not gonna pay.", "so, I'm gonna... I'm gonna go."),
#  ('Look, you can fly royalty express for a year, or you can leave the airline.',
#   'look, you can fly with Royalty Express for a year or you can quit.'),
#  ('That just slipped out... But I guess.', 'I slipped!'),
#  ('What plans? What are you talking about?', 'what are you talking about?'),
#  ('I try to imagine what that must have been like... ...seeing everyone around youfall over dead for no apparent reason.',
#   "I'm trying to imagine what it must be like to see everyone around you die for no apparent reason."),
#  ("But I can hardly remember what it's like to make love... and if I forget that, then I'll die.",
#   "I don't even know what it is like to make love, if I forget it, I'm going to die."),
#  ('But, how are we gonna get there?', 'but how do we get there?'),
#  ('There’s a conflict between business interests and moral values.',
#   'there is a clash between commercial interests and moral values.'),
#  ('The intervention agency shall examine offers.',
#   'the intervention agency shall assess the offer.'),
#  ('Watch the braces.', 'watch out for braces.'),
#  ("No, I don't wanna see anyone.", 'yeah, I wanna know.'),
#  ("Captain's log, stardate 46693. 1.", "captain's log, stardate 41263.4."),
#  ("You'il be late for your first day back at school.",
#   "you're gonna be late on your first day of school."),
#  ('41 In the annex to the application, the applicant submitted neither the contract documents of France 2 and France 3, nor even its own contract documents.',
#   '41 The applicant did not provide, in the annex to the application, the tender documents of France 2 and France 3, nor in its own procurement documents.'),
#  ('What does... what does it mean?', 'does... does it make sense?'),
#  ('I heard you came by horse.', 'I heard what I heard.'),
#  ("Leia's lip twitched.", "it's Lip."),
#  ('He came back up the stairs, and again looked in through the stained glass.',
#   'he went up the stairs again and looked over the colored glass.'),
#  ('A lot of valuable information can be gained by reading comic books.',
#   'a lot of valuable information can be obtained by reading comical.'),
#  ('He Hu, Tie Zhu...one takes the left, the other takes the right.',
#   'he Hu, Tie Zhu, one goes to the left, second right.'),
#  ("My dear, we both know what's expected of us, don't we?",
#   "my dear, we both know what's expected of us."),
#  ('The IPA regulation is designed to support the progress of the region towards accession.',
#   'the IPA Regulation aims at promoting the direction of the region for accession.'),
#  ("No, because you're a gentleman, you have class.",
#   "no, because you're a gentleman, you have a level."),
#  ('Orders OHIM to bear its own costs and three-quarters of the costs of Mr Nicolas Wessang;',
#   'orders OHIM to bear its own costs and three quarters of the costs incurred by Nicolas Wessang.'),
#  ('So get ready.', 'then be ready.'),
#  ('I also needed to get my emotions under control.',
#   'and I needed to get my feelings under control.'),
#  ("What's going on over there?", "what's going on with tradition?"),
#  ("It's just family stuff...", "it's family stuff."),
#  ("I'm so, so sorry.", 'so far, so.'),
#  ("You haven't told her.", 'I told you.'),
#  ('| No | No | No | 3 | 7.', '| | |'),
#  ('It was fortunate Dr McFee witnessed the whole thing and whisked her inside, no doubt for one of his fortifying draughts.',
#   'fortunately, Dr. McFee saw the whole thing, and he drove her in, no doubt for some of his restorers.'),
#  ('We also have a photo of Faisel and the girl',
#   'we also have a picture of Faisel and the girl.'),
#  ('He means like the rappers.', 'he means rappers.'),
#  ('The other participants may only withhold their agreement if they demonstrate that implementation of the indirect action or their legitimate interests will be significantly impaired thereby.',
#   'the other participants may withdraw their consent only if they show that the implementation of the indirect action or their legitimate interests would be seriously damaged.'),
#  ('Yeah. Come on in.', 'come on in.'),
#  ('Can you describe the perp?', 'can you describe her?'),
#  ("Well, let's talk about that.", "if you need to talk, let's talk."),
#  ("Michel Foucault's Force of Flight.",
#   "Bernauer, James, Michel Foucault's Force of Flight."),
#  ('Maybe you should get it for Ali.', 'maybe you should take Ali.'),
#  ("Must've been a real nice place.", 'must have been a nice place.'),
#  ('"He merely confirmed our assessment.',
#   '"he merely confirmed our findings.'),
#  ("That's good enough.", "that's good, that's good."),
#  ('Dude...', 'man...'),
#  ('I mean, it could have been fucking puka shells.',
#   'I mean, it could be bloody shells.'),
#  ('Do the right thing.', 'right, right.'),
#  ("I'd rather take it up with you.", "I'd rather be with you."),
#  ('I swear it, I will.', 'I have nothing to swear on, but I swear it.'),
#  ('She was run off the road by a big Cheyenne man with, and I quote, "a big scar under his eye."',
#   'he pushed her out of the road by a large Cheyenne... and I quote, "with a large scar below his eye."'),
#  ("I'm not ashamed of what I am.", "I'm not ashamed of this."),
#  ("I don't cook for somebody that's not nice to my friends.",
#   'I can cook for you.'),
#  ('Motherfucker, wake up!', 'Daniel, wake up, wake up!'),
#  ('I spoke to every one of the nurses on that floor.',
#   'I talked to every nurse on that floor.'),
#  ('He\'s a street artist, goes by "Jpeg."',
#   'he\'s a street artist known as "Jpeg."'),
#  ("There's nothing I wouldn't do.",
#   "there's nothing in the world I wouldn't do."),
#  ('‘LV00028 RIGA-MN’ (b) the entry for the following local unit is deleted:',
#   '"LV00028 RIGA-MN" (b) the entry for the following local unit is deleted:'),
#  ('I know you are, Sam.', '"I know, you know, I know who you are.'),
#  ("Let's start with you, monti.", 'start with this.'),
#  ('prudential requirements to ensure their viability and the protection of their users.',
#   '15.6 Identification and evaluation of property and infrastructure should be used to determine their ranking according to the relative importance of their protection.'),
#  ('|| "Technology" according to the General Technology Note for the "use" of goods specified in 2B350 to 2B352.',
#   '| | "Technology" in the meaning of the General Technology Note for the "use" of goods specified in 2B350 to 2B352.'),
#  ('"Lift in five minutes."', 'five minutes five'),
#  ('I came in.', 'I came for you.'),
#  ('To be a good translator, I thought one must understand the culture.',
#   'worth a good 13, 15 per cent of his GDP'),
#  ("That's not necessary.", "it's not necessary."),
#  ('You walk wrong and you stand wrong.', 'you go wrong and you go wrong.'),
#  ("It's been the happiest 11 years of my life and I can't imagine not being married to her.",
#   "it was the happiest 11 years of my life, and I can't imagine not being with her."),
#  ('I found a place in the suburbs and job as a council driver.',
#   'I found an apartment in the suburbs and a job as a driver.'),
#  ('Thankyou, charlie.', 'thank you, Charlie.'),
#  ('They checked their weapons.', 'they checked the guns.'),
#  ('"Yvette is a council toady.', '"Yvette is an asswipe of advice.'),
#  ('Is that the Henderson kid?', "Henderson's son?"),
#  ('The final report on the project was never forwarded.',
#   'a final report of the project has never been passed.'),
#  ('That is not the world I live in since...',
#   "it's not the world I live in from..."),
#  ("You know, if I lose Mandy, I've lost all three of my daughters in one week.",
#   'if I lose Mandy, I lose all my daughters in one week.'),
#  ('Armstrong stepped out and turned back and offered his hand to his wife.',
#   'first Armstrong stepped out, then turned and handed his hand to his wife.'),
#  ('We kill him, the mob kills us.', 'we kill him, his people kill us.'),
#  ("I'm so sorry. Please, please, please go.",
#   'please, please, please listen.'),
#  ('In the dreams he tells me where to go, because in the dreams he can talk.',
#   'the dreams, the impossible dreams.'),
#  ("No! He's dead!", "he's dead!"),
#  ("So, um... I'll see you tomorrow?", 'see, you see?'),
#  ('It was a terrible thing. Terrible.', 'terrible thing, terrible.'),
#  ("A burrito and couple of beers, what's the big deal?",
#   "what's your burrito?"),
#  ('The required %s driver is already on the system.',
#   'the required driver for% s is already installed on the system.'),
#  ('He asked me to give you this.', 'I asked you to.'),
#  ("I'm willing to take the risk.", "I'm willing to risk it."),
#  ('physicians to discuss this risk with patients if they become or plan to become pregnant;',
#   'therefore, it is necessary for your doctor to treat the risk with a patient if they become pregnant or are planning to become pregnant;'),
#  ('On this basis the claim of the applicant had to be rejected.',
#   'in addition to the ex ante controls described above, ex-ante and ex-post evaluations will be carried out on the basis of an annual risk analysis.'),
#  ('Do you see the fear, people?', 'you see the fear?'),
#  ('There was much celebrating among all the men in the garrisons, both Tsurani and LaMutian.',
#   'all the men of both Lamut and the Tsurani were celebrating together.'),
#  ('Must be something he wants kept private.',
#   'it must be something he wants to keep in private.'),
#  ('In that context, he/she shall regularly inform as well as respond to any specific ad hoc requests for information from the Governing Board and the Scientific Committee.',
#   'in this respect, the Management Board and the Scientific Committee shall regularly inform and respond to all their specific ad hoc requests for information.'),
#  ('Nice boots. Niiiiice boots. Hey.', 'very nice boots.'),
#  ('Look, I tried everything to get him to stop.',
#   'we tried, I tried everything.'),
#  ('Eventuelle strategier eller politiske vedtak innen EU som kan påvirke EUs import av skogindustriprodukter vil kunne få store konsekvenser for den norske skogsektoren.',
#   'any strategies or strategies referred to in the EU are not available to the EUs import av skogindustriprodukter vil kunne få store konseser for den norske skogseoren. "'),
#  ('In regard to non-life insurance, Member States may grant authorisation for the groups of classes listed in Part B of Annex I.',
#   'for non-life insurance, Member States may issue permits for the sectors of the sectors listed in Part B of Annex I.'),
#  ("She's in a play, and I promised dorothy I wouldn't miss it.",
#   'she promised she would do it, and I kept reminding her.'),
#  ('Let go, let me go!', "let's go, let's go, let's go!"),
#  ('That just slipped out... But I guess.', 'they slipped.'),
#  ('I just worry.', "I'm just worried."),
#  ('We need to build 2 copperdams between the shore and this side of the island.',
#   'between the shore and this side of the island we have to build two artificial headwinds.'),
#  ('The naked streets of Bethesda can be so dark and dangerous.',
#   'the deserted streets are so dark and dangerous.'),
#  ("You're not afraid of me.", 'to be afraid.'),
#  ('No, I tried that.', 'I tried!'),
#  ('7 – These periods lasted between 3 months and more than 18 years.',
#   '7 - This period was between three months and more than 18 years ago.'),
#  ('Carl tried to hang himself... twice.', 'Carl tried to hang himself.'),
#  ("I know you're scared.", 'I know you know.'),
#  ('The church isn\'t open yet, and I\'m not finished hoovering."',
#   'the church isn\'t open yet, and I\'m not done with cleaning. "'),
#  ("What's the matter with the doc?", "what's the matter with you?"),
#  ("Captain's log, stardate 46693. 1.", "captain's Log, Stardate 54282.5."),
#  ('You have a nice night, Connie.', 'good night, Connie.'),
#  ('The editor yawned, but the author thought it was a great idea.',
#   'the publisher was yawning, but the author thought it was a great idea.'),
#  ('Filgrastim may be given as a 24 hour subcutaneous continuous infusion or subcutaneous injection.',
#   'filgrastim may be administered as a 24-hour continuous subcutaneous infusion or subcutaneous injection.'),
#  ('Bye George.', 'hey, George.'),
#  ('My son forgot whose turn it was today, so...', 'I forgot...'),
#  ('You would have made a valuable ally.', "you'd be a valuable ally."),
#  ('I heard you won a medal.', 'I heard you got a medal.'),
#  ('"I\'ve been fooling myself."', '"I fooled myself."'),
#  ('Please tell me if you need something', 'tell me if you need anything.'),
#  ('An old man dies, a little girl lives.',
#   'old man dies, little girl will live.'),
#  ('But the good news is that all the players were wearing action cameras.',
#   'the good news was that there were people all over the world.'),
#  ("I'm supposed to have a date tonight.", "I'm supposed to be dead."),
#  ("I'm sure you've heard.", "are you sure? - I'm sure."),
#  ("No, I'm all right, thank you.", 'thank you, thank you.'),
#  ('First there was the premature announcement that many extracolonial messages had been decoded.',
#   'the first was an early announcement that a sizable non-colonial message had been decimated.'),
#  ('The Remote Installation service encountered an error while reading its settings from the directory service.',
#   'an error occurred reading your settings from the remote installation service.'),
#  ("Hey, I know I still can't take point, but let me know when they get here.",
#   "look, I know, I still can't run, but let me know when he gets here."),
#  ('The Warriors - Next in line.', 'Warriors - next in order.'),
#  ("It ain't till next week, week after.", "it's next week or next week."),
#  ('In addition, the proposal aims to update the Regulation according to the needs of a rapidly evolving statistical domain.',
#   'the proposal also seeks to update the Regulation according to needs rapidly evolving statistics.'),
#  ('I was there when your father first brought you in, and then they started the testing.',
#   'I was there when your father first brought you.'),
#  ("Don't underestimate them.", "we don't underestimate anyone."),
#  ("Your mom told me that you're gonna go back to Wyoming with her.",
#   'your mom told me you were going back to Wyoming.'),
#  ("I'm going to make another pot of tea.", "I'm going to meet Dean."),
#  ('To this end, transitional arrangements and a gradual build-up of capacity will have to be used.',
#   'this is a transitional package.'),
#  ('"to the Canyon of the Crescent Moon, to the temple where the cup that..."',
#   '"to Half Moon Canyon, to the Temple, where the cup..."'),
#  ("I've never seen this movie before... but this is some serious capitalist propaganda.",
#   "I've never seen the film before, but it's quite capitalist propaganda."),
#  ("I didn't tell them where they could find us.",
#   "I didn't tell them where they found us."),
#  ("It wasn't in very good shape.", "he wasn't in particularly good shape."),
#  ("Listen, Alistair, I just wanted to say, I'm not a window cleaner.",
#   "listen, Alistra, I just wanted to tell you I'm not a window washer."),
#  ("We're both willing to do whatever it takes to keep him.",
#   "we're both willing to do what we need to keep him."),
#  ("They're listening to us.", "they're listening."),
#  ('He thought his life insurance could clear his debt.',
#   'you know, he thought his life insurance policy could cover his debt.'),
#  ('"Doing the nasty"?', '"does ugly"?'),
#  ('Well, well, well, any idea where we might be able to find these gentlemen, Reverend?',
#   'okay, well, any idea where we might find these guys, Reverend?'),
#  ("(f) require that any subsequent capitalization have the same treatment as the branch's initial capital;",
#   '(F) may require that the subsequent capitalisation be given the same treatment as the initial capital of a branch;'),
#  ("No, I'm not this time.", 'no, not this time.'),
#  ("You're not afraid of me.", "I'm not afraid of you."),
#  ("It's about Rose.", "not about you. It's about me."),
#  ('I told you how I got in.', 'I told you how I got here!'),
#  ("- Making sure you're still paying attention.",
#   "I'm just making sure you're still paying attention."),
#  ("Can't tell you how many times I have dreamed of that.",
#   "you don't know how many times I've dreamed of it."),
#  ("Glen rose, but we didn't see a sign... didn't know if we'd gone too far, not far enough.",
#   'far, far worse.'),
#  ('Do you approve of this?', "you don't approve?"),
#  ('I was thinking, remember our game from the summer?',
#   'I remember Vietnam as if it were yesterday.'),
#  ('His trust in your sword was extraordinary.',
#   'his confidence in your sword is admirable.'),
#  ("I'm sorry to bother you... ...but you look like a person who appreciates fine art... ...so I wanted your opinion.",
#   "I'm sorry to bother you...... but you look like a man who knows the art...... so you'd be interested in me."),
#  ("I'm sorry this is the reason, but I'm glad I get to see you.",
#   "I'm sorry about the reason, but I'm really happy to see you."),
#  ('"I\'m glad it finally woke up."', "I'm glad you like it."),
#  ('It\'s called "don\'t talk to cops."',
#   'captain Gregson wants to talk to you.'),
#  ("We're all the children... ...of the universe.",
#   'we are all the children of the universe.'),
#  ('I know that now, I know that.', '"I know, I know.'),
#  ('It hurts me.', 'it hurts!'),
#  ("Fong, don't believe her, I'm the real one.",
#   "I don't believe you believe."),
#  ("ROBBINS: I'm at Russell's crime scene. He was scheduled to meet me here an hour ago.",
#   "I'm at Russell's crime scene. He was supposed to be here an hour ago."),
#  ("You really think I'm going to let you walk free around this fucking planet?",
#   "do you really think I'm gonna let you walk around on this planet?"),
#  ('It was a terrible thing. Terrible.', "it's a terrible, terrible thing."),
#  ('Listen to me, Hercule, and you will learn something.',
#   'you have to learn.'),
#  ('Choose shade of gray based on:', 'choose a shade of grey by:'),
#  ('The war to end all wars.',
#   'and in the end, all economic gains will be absorbed and there will be fewer incentives for all of these players to be so aggressive.'),
#  ('And a second clown mask.', 'a clown...'),
#  ('If you do not want to wait, we can move party at home.',
#   "if you don't want to wait, we can move the party room."),
#  ('What is the significance of it?',
#   'what is the real significance of Christmas?'),
#  ("I'm out here.", "I'm here."),
#  ('This annotation may be used only on attributes and property elements',
#   'this record can only be used for attributes and property elements.'),
#  ('I will not accept failure!', 'I accept.'),
#  ('Have a great day.', 'have a nice day.'),
#  ('He suppressed his anger, tried to talk reasonably.',
#   'he suppressed his anger, tried to speak with reason.'),
#  ("Come on, let's do it. It might be amusing.", 'please do it.'),
#  ('I told odessa we were getting married, And she freaked out.',
#   "we're getting married."),
#  ('Hello, Mary.', 'good evening, Mary.'),
#  ("I should have believed you when you told me that you and Liam didn't, you know.",
#   '"I believed you.'),
#  ("That's the beauty of this system.", "that's the beauty of it."),
#  ('What are you doing In my rooms?', 'what are you doing in my room?'),
#  ('A lot of room, apparently.', 'a lot, a lot of days.'),
#  ('"I can\'t remember either.', '"I can\'t remember."'),
#  ('Because he comes down a chimney.', 'because he came down the chimney.'),
#  ('Summary execution was not exactly unknown in either Iran or Iraq, an efficient way of dealing with dissidents, real or imagined, in both countries.',
#   'mass executions were not unknown in Iraq or Iran; in both countries it was an effective way of dealing with dissidents, whether real or only imagined.'),
#  ("Inside was the body of a Sartan female, but it wasn't Lya!",
#   "the body of a Sartan woman lay there, but it wasn't Lya!"),
#  ('And yet, I blame society.', 'I blame you'),
#  ('Excellent, Jar Jar, assuming the pirates still have Count Dooku to trade.',
#   'great, Jar Jar, provided the pirates still have Count Dooku in exchange.'),
#  ('(20) Article 29e(2), the following subparagraph is added:',
#   '(B) The following subparagraph is added to the first subparagraph:'),
#  ("I think you're exaggerating.", "I think you're overreacting."),
#  ('Queries are used to import external data into Excel, but harmful queries can be used to access confidential information or write information back to a database.',
#   'inquiries are used to import external data into Excel, but they can also be used to obtain confidential information or to resubmit to the database.'),
#  ("They're celebrating already.", "they're celebrating."),
#  ('Coffee, extra black, extra no sugar, and real warm.',
#   'coffee, extra strong, extra sugar and really hot.'),
#  ("Sir, respectfully, if you can't afford to tip, you can't afford to eat here.",
#   "Sir, with all due respect, if you can't afford tips, you can't afford to eat here."),
#  ('Out of Belfast?', 'Belfast?'),
#  ('According to the legend,', 'according to legend'),
#  ("I don't believe you, major.", "I don't believe you believe."),
#  ("I haven't said anything. I'm trying to figure this out.",
#   "I'm trying to understand the rules here."),
#  ("I'm glad I have this.", "I'm glad to have you."),
#  ('Dead.', 'dead...'),
#  ('I think this is what Doctor Rogers warned us about.', 'I warned you.'),
#  ('General requirements for safety - Collateral standard:',
#   'general requirements for the safety of Group Standard:'),
#  ('There are a lot of girls called Charlotte.',
#   "there's a lot of girls named Charlotte."),
#  ('Aye, makes sense.', 'that makes sense.'),
#  ('It was written later in his life, in 92 PC, to be precise, as he worked in the service of his thane.',
#   'he was written later in his life, in 93 before the Catriona, to be precise when he was working in the service for his teat.'),
#  ('This bomb is going to go off.', 'this is the bomb.'),
#  ('Will you tell him he has got to slow down this car!',
#   'tell him to slow the car down!'),
#  ('No yelling!', "don't yell!"),
#  ("I'm so sorry. I should've listened to you.",
#   'I should have listened to you.'),
#  ('The transfer of border control from the military to the civilian authorities is proceeding.',
#   'there is a shift in the delegation of border controls from the military to the civilian authorities.'),
#  ('Watch my chin.', 'watch your chin.'),
#  ("Nobody's gonna hurt you. It's okay.", "no one's gonna hurt you."),
#  ("I'd managed to just ... carry on.", 'I managed to escape.'),
#  ("Yeah, but even they weren't immune to the financial crunch.",
#   "yeah, but they weren't immune to the financial crisis either."),
#  ('Sorry, EB.', 'sorry, E.B.'),
#  ('I insist that you keep it.', 'if you insist.'),
#  ('Uh-huh, um... Oh, my God, is, is he all right?', 'oh, my God.'),
#  ("I don't recognize you", 'I didn\'t recognize you! "'),
#  ("What, you think I'm going to beat you?",
#   "what, you think I'm gonna hit you?"),
#  ('The giants have always been gentle. Why are they treated like slaves?',
#   'the giants have always been nice. Why do they treat them like slaves now?'),
#  ('I was always amazed at how quiet everything was.',
#   'I was intrigued by how quiet everything was.'),
#  ("Outside the tent we heard Targo's voice.", 'this tent.'),
#  ('Override volume re-labeling collision and merge the volumes?',
#   'article 2 Wine zones in which wines may have the total alcoholic strength by volume of 20% vol.'),
#  ('You can tell me the truth.', 'you can tell them, or you can tell me.'),
#  ("Can you believe Brian has photo approval and I don't?",
#   "would you believe Brian can approve the photos and I can't?"),
#  ('Would I have been happier with the other tie?',
#   "wouldn't I be happier with another tie?"),
#  ("I can't believe you never showed this to me.",
#   "I can't believe you didn't show me."),
#  ('For example, a box of cereals containing a small surprise article of a negligible value such as a plastic figure/toy or stickers would not be classified separately.',
#   'for example, a cereal box containing small surprises of slight value such as a plastic dummy / toy or sticker would not be recorded separately.'),
#  ('How long is he here for?', 'how long will he be here?'),
#  ("It wasn't business, I was just building contacts.", 'the building.'),
#  ('I love you, Joe.', 'we love you, Joe.'),
#  ('The Commission works with Member States and the GFCM on improvements.',
#   'the Commission is working with the Member States and the GFCM to improve the situation.'),
#  ('I knew her', 'I knew Jim knew.'),
#  ("It's the rebel Skitters.", 'rebel Isil.'),
#  ('Yeah, come on, Nullah.', 'come on, come on, come on.'),
#  ('I heard your mother say that once.',
#   "that's what I heard your mother say."),
#  ("Our army will still land, even if we'd all been killed back in the forest.",
#   "our army will land anyway, even if we're both dead in the woods."),
#  ('Most species stay in stasis for long periods of time.',
#   'many species remain stationary for long periods of time.'),
#  ('I like that guy.', 'I like you like that.'),
#  ('I came in.', 'you came.'),
#  ('The son of a bitch, Hood thought as he hung up the secure phone.',
#   'you son of a bitch.'),
#  ("You think I'm giving anything back to him?", "I'm giving you..."),
#  ('"A shadow deep in our Honored Matre past," Murbella said.', 'deep, deep.'),
#  ('It was a long time ago.', "it's a long, long, long time ago."),
#  ('Oh, yeah? Since when?', 'since when?'),
#  ('Q, I strongly suggest that you cooperate.',
#   'and I suggest you remember that.'),
#  ('And I think I charge $25,000 for a boy.', 'I charge $25,000 for the boy.'),
#  ('"Wal, I reckon I\'ll be some indebted to you, Miss Majesty, an\' all your guests," replied Stillwell, warmly.',
#   'I reckon you know.'),
#  ('I have a proposition for you, Inspector.',
#   'we have a proposition for you.'),
#  ('"But he had no pipe."', '"he didn\'t have a pipe."'),
#  ('Why would someone throw a shake at you?',
#   'why would anyone throw it at you?'),
#  ('I didn’t realize someone was holding my hand until whoever it was squeezed it lightly.',
#   "I didn't realise someone was holding my hand until it was lightly squeezed."),
#  ('If you love him, my Bella... ..save him.',
#   'if you love him, my Bella, save him.'),
#  ('Put on a smile, and stay out of trouble.',
#   'nice smile and stay out of trouble.'),
#  ("Hey, that's exactly what I'm talking about.",
#   "I'm done talking about Lew."),
#  ("I can't help it, it's in my nature.",
#   '"I couldn\'t help it, it\'s in my nature."'),
#  ('This results in the lowest level of ending stocks since the implementation of the 2006 reform of the sugar sector.',
#   'the result is the lowest level of final stock of stocks since the introduction of the sugar reform in 2006.'),
#  ("I saw this episode last night at Mom's.",
#   "I saw that part last night at my mom's."),
#  ('"I know how you feel.', 'so I know how you feel.'),
#  ('It belongs to Jeremy and Elena.', 'it belongs to you.'),
#  ("As the red team is going full steam ahead onto the high seas... back at Hell's Kitchen, the blue team...",
#   "while the red team is headed full wide on the open sea, the blue team is in Hell's Kitchen..."),
#  ('Food, drinks, drugs.', 'food, drink, even medicine.'),
#  ('Many of you have probably noticed the new face sitting here.',
#   'many of you have noticed, the new face is sitting here.'),
#  ('"Nice bed," he said, patting the coverlets encouragingly.',
#   '"no," McGovern said, patting him on the shoulder.'),
#  ("Are you sayin' that because it's a great idea?",
#   'are you saying that because this is an excellent idea?'),
#  ('So descend into Huautla Plateau in Mexico.',
#   'the descent into Huautla Plateau in Mexico.'),
#  ('And I can pull them off when I want to work with them.',
#   'I can take them off if I want to work with them.'),
#  ('We went out in search of a way to say good-bye to an absent father, but we found a lot more than that.',
#   'we were on our way in to find a way to say goodbye to the absent father, but we found much more than that.'),
#  ("Dog's up.", "the dog's upstairs."),
#  ("I don't cook for somebody that's not nice to my friends.", 'Cook it.'),
#  ("What's on the file?", "what's this file?"),
#  ("That's good enough.", "that's good, good, good."),
#  ('"The Goldfinch" is a literary masterpiece.',
#   '"the Goldfinch" is a masterpiece.'),
#  ('That probably means he has her.', "that probably means he's got it."),
#  ('Yeah, I thought that was some kind of animal attack.',
#   'yeah, I thought it was an animal attack.'),
#  ('"My life was involved too," Saliman shrugged.',
#   '"it was my life," Saliman shrugged.'),
#  ('I wanna see the end.', 'I wanna fuck the world.'),
#  ('That man was Captain Fábio.', 'he was Captain Fábio.'),
#  ('Oh, this is your case.', "it's your case."),
#  ('Yeah, I was just wondering if you had that present for me yet.',
#   "I was wondering if you'd..."),
#  ("There's no one here.", "there's no one."),
#  ("You'il threaten me?", 'threaten her?'),
#  ("But I'm-- I'm not afraid anymore.", "I'm not afraid of you."),
#  ("What's the matter with me, Mark?", "what's the matter with you?"),
#  ('Originally the Member States were required to submit their reports by 30 June 2012.',
#   'initially, Member States were to report by 30 June 2012.'),
#  ('It was an important job, and he was the best man for it.',
#   'it was an important assignment, he was the best man on it.'),
#  ("That's in London.", 'London.'),
#  ("Let's hope it's worth it.", "it's worth it!"),
#  ('What, what happened?', 'what, what, what?'),
#  ("Excuse me, I'm terribly sorry to disturb you...",
#   "I'm sorry to disturb you."),
#  ("There's a lot of work.", "that's a lot."),
#  ('So, what brings you to town?', 'what brings you here?'),
#  ("That's my favorite one of them.", "that's your favorite."),
#  ('I know, but I just recieved it.',
#   'but believe me, he told me what I needed to know.'),
#  ('IV – My analysis 36.', 'IV - Analysis 36.'),
#  ("First one's a warning... ...Padre.", 'first with a warning... Father.'),
#  ('Send it to the lab', 'to the lab.'),
#  ('That sounded a little desperate.', 'that sounded logical.'),
#  ("It's the Sounds of Silence.", "that's the sound of silence."),
#  ('Not your lucky day.', "you don't have a lucky day."),
#  ('Too dangerous.', 'very dangerous.'),
#  ('I knew her', 'I knew I knew the Mutt.'),
#  ("Come with me, let's go out to see the stars.",
#   "come with me, let's go watch the stars."),
#  ('Understood, but we recommend some changes.', 'but we recommend changes.'),
#  ("What's the thing you like best about it?", 'what did you like best about?'),
#  ('The ECB objects neither to the new NACE structure nor to its detailed classification.',
#   'the ECB has no objections to the new structure of the NACE or its detailed classification.'),
#  ('Five years after the World Summit on Sustainable Development (WSSD 2002) there is only modest progress on some WSSD goals and targets.',
#   '8 goals.'),
#  ('Do we have any of those?', 'any of you?'),
#  ('Paul watched him sometimes.', 'Paul looked over at him sometimes.'),
#  ('Can you help... to scrub my back?', 'will you help me scrub my back?'),
#  ("Can you imagine walking by your kid's empty bedroom, not knowing where he is?",
#   'can you imagine walking around the empty room of your kids and not knowing where he is?'),
#  ("I'm in luck today.", "I'm lucky today."),
#  ('Whoa, Baby!', 'hey, baby!'),
#  ('Peter Hopkins was a barrister back then, he was appointed to lead the investigation.',
#   'Peter Hopkins was then a solicitor, assigned to lead the investigation.'),
#  ('I was no longer a threat.', 'we were no longer a threat.'),
#  ('Do not give by injection under the skin (subcutaneously).',
#   'the Taj is now under way.'),
#  ("I wouldn't want anything in the world to happen to you.",
#   "this can't happen to you."),
#  ('I got it. I win.', 'I got it, I got it, I got it.'),
#  ("I'm gonna ask him.",
#   "yeah, I'm gonna need you to come and make a statement."),
#  ('Unbelievably sorry.', "I'm incredibly sorry."),
#  ('Scotty. Better than Philadelphia this time.',
#   'this time better than Philadelphia.'),
#  ('The rest of the stolen bullion was recovered at the crime scene... ... along with three high-flying hijackers apparently stranded...',
#   'the rest of the stolen loot was found at the crime scene...... along with three high-profile hijackers apparently stranded...'),
#  ('Oh, thanks for the invitation.', 'yeah, thanks for the invite.'),
#  ("Here's her desk.", "that's her desk."),
#  ("I'm not helping, am I?", 'am I who I am?'),
#  ("She'll have to wear a wire.", 'we have to wear.'),
#  ('This new model could have a broader scope and should cover as many types of evidence as possible, taking account of the measures concerned.',
#   'this new model could have a wider range, should cover as much evidence as possible and take into account the measures in question.'),
#  ("By your soul's salvation?", 'on the salvation of my soul?'),
#  ('You wanna keep Irisa safe.',
#   "so, good luck with that, and we're gonna keep New York safe for you when you get back."),
#  ('Instead he lay on the carpet smiling.',
#   'instead he lies on the carpet and smiles.'),
#  ("You kill him, they'il never open that door.",
#   "if you kill him, he'll never open the door."),
#  ('Insert electronic postage', 'insert an electronic stamp'),
#  ('He will heal us.', 'it will heal.'),
#  ('Oh! Wow, Sean.', 'wow, Sean.'),
#  ('I knew her', 'I knew I knew you from somewhere!'),
#  ("I'm sorry, I'm on call.", "I'm sorry."),
#  ('I got stuck in some traffic.', "I'm stuck."),
#  ('Why is that better? ...That Katie tested herself, her numbers were high, she gave herself some Insulin... or what she thought was Insulin.',
#   'that Katie tested herself, her results were high, so she took some insulin... or thought it was insulin.'),
#  ('Look at this place.', 'look at the place.'),
#  ('If China can successfully rebalance its economy and shift to consumption-based growth, its trading partners could benefit enormously from a huge retail market.',
#   'if China is able to balance its economy successfully and move to consumption-led growth, its trading partners could benefit enormously from its trading partners.'),
#  ('What will you call him?', 'what do you call him?'),
#  ("You, too! Both of y'all.", 'you too!'),
#  ('The Conditions page cannot be displayed.',
#   'unable to display page Conditions.'),
#  ('Mrs Wheelock?', 'and Mrs. Wheelock?'),
#  ('We were in trenches before the attack, Colonel... ...when the gun of the soldier beside me went off.',
#   'in the trenches?'),
#  ('Witness was a block away.', 'the witness saw it from a block away.'),
#  ("I don't cook for somebody that's not nice to my friends.", 'I can cook.'),
#  ("Did you borrow your father's radio without permission again?",
#   "did you borrow your dad's radio again?"),
#  ('Hey, Max, you home.', 'hey, Max, you home?'),
#  ('You ever, uh, run a marathon before?',
#   'have you ever run a marathon before?'),
#  ('Such firm shall be a member of an internationally recognised supervisory body.',
#   'this audit company is a member of an internationally recognised supervisory body.'),
#  ('You may have used an aggregate function, such as Count, in a design grid or in a calculated control or field.',
#   'aggregate functions such as the Count can be used, such as the Count, in a calculated control or field, or in a return grid.'),
#  ("It's freezing cold.", "it's freezing!"),
#  ('But tell me mate... will there be war?',
#   'but tell me a friend... will there be a war?'),
#  ('Mueller sat up straight, staring at Baird, then he laughed harshly.',
#   'Mueller sat upright, stared at Baird, and laughed harshly.'),
#  ('I just punched him in the face.', 'I punched you in the door.'),
#  ('Secondly, within the internal market, the rise in production costs varies by reason of the disparity in national reduction objectives and allocation policies.',
#   'secondly, the increase in the cost of production in the internal market is changing due to differences between national emission reduction targets and between national allocation policies.'),
#  ("It's a zoo transfer!", "it's a zoo transport!"),
#  ("It'sn me or it's on tucker!", "it's on me or on Tucker!"),
#  ('Save Site as Template', 'save Web as Template'),
#  ('She made them rip out the tiles.', 'she let them rip the tiles.'),
#  ('He follows me everywhere now.', "he's following me everywhere."),
#  ("Some are useful, some aren't.", "some can do it, some won't."),
#  ("if they'd happened while she was working as she claims, somebody would've filed an injury report.",
#   'if it had happened to her at work, she claims, someone would have filed an injury report.'),
#  ('Open it. "I told you so."', 'I told you not.'),
#  ('It was impossible that they could hear him, but he pointed to the switch, for they had it locked from inside.',
#   "that's impossible."),
#  ("If you've got a better plan, tell me!",
#   'if you have a better plan, you can tell me.'),
#  ('This is maybe news to you, but they suffer too.',
#   "that's probably news to you, but they're suffering too."),
#  ("It's about the original couple.", "that's the original."),
#  ('3.6. Specific rules concerning slicing, grating, packaging, etc. : 3.7.',
#   'specific rules for slicing, grating, packaging, etc.:'),
#  ("So we're hoping that you could identify something else.",
#   "that's what we're hoping."),
#  ("I'm gonna say it.", "so, I'm gonna... I'm gonna go."),
#  ("Oh, it's just like I said, that crazy... ...Bert, roaming the halls.",
#   "but it's just like I said, fool...... Bert, wandering the hallways."),
#  ('Not that test.', 'not the test.'),
#  ('To ensure effective delivery, the Commission services will develop operational guidelines for the implementation of the European Year.',
#   'complete the implementation of the reforms of state-owned enterprises, in particular to ensure separation of ownership and management functions, and closely monitor compliance with the reform requirements.'),
#  ('România sanofi-aventis România S.R.L.',
#   'Česká republika sanofi-aventis, s.r.o.'),
#  ('You seem anxious, Mr. Nettinger.', 'you seem sure.'),
#  ('The first sentence of Article 108(3) TFEU imposes on the Member States the obligation to inform the Commission of any plans to grant or alter aid.',
#   'the first sentence of Article 108 (3) TFEU provides for the Member States to notify the intention to grant or modify the aid.'),
#  ("I'm worrying about you.", "I'm worried about you."),
#  ("Like you're a kid almost.", 'the kid.'),
#  ('"Professor Dumbledore," he said hurriedly."', '"professor," he said.'),
#  ("The question, then, is who's taping you... the police, the feds...",
#   "the question is, who's recording you: Police, Feds..."),
#  ("It's been patented as a cure for the monkey virus, without mentioning the human virus, of course.",
#   'we have obtained a patent for the treatment of a monkey virus, of course there was no mention of the human virus.'),
#  ("We can make a world that's paradise because we'll always rule it.",
#   "it's paradise!"),
#  ('Elderly people (age 65 years and older)',
#   'older people (65 years and over)'),
#  ('When herod hears a new king is being born in Bethlehem, he orders the murder of every infant boy.',
#   'not before her baby is born.'),
#  ("I don't want to hear this!", "I don't want to listen to this!"),
#  ('I knew her', 'because I knew you knew.'),
#  ('( 21 ) OJ L 184, 17.7.1999, p.', '23. (22) OJ L 184, 17.7.1999, p.'),
#  ('Well, thank you, Hogan.', 'thank you, thank you, thank you.'),
#  ('The fresh fruit from which other types of canned fruit are manufactured have different codes in the Combined Nomenclature at the six-digit level.',
#   'fresh fruit from which other types of preserved fruit are obtained has another six-digit numerical code of the Combined Nomenclature.'),
#  ('(b) new safety developments are implemented;',
#   '(B) new developments in the area of safety are in place;'),
#  ('You junkie son of a bitch.', 'you stinking son of a bitch.'),
#  ("There's still 13 trillion dollars circulating in the U.S. economy.",
#   'five dollars.'),
#  ("Look, I'm... I'm trying to tell you...",
#   "I'm trying, look, I'm trying to help you."),
#  ("I'm his mother, I would.", "I'm his mother."),
#  ("It's really embarrassing.", 'this is so embarrassing.'),
#  ('I wondered when you would tell me.', "I wondered when you'd come."),
#  ('"I had a little something to do with it, too."', 'a little, a little.'),
#  ("Unless it's exposed to oxygen.", "if he's not exposed to oxygen."),
#  ('PSF made from PTA/MEG and PSF made from recycled PET bottles indeed constitute two different PSF types within the product scope of PSF.',
#   'the PSF produced from the PTA / MEG and PSF produced from recycled PET bottles actually represent two different types of PSF under the definition of PSF.'),
#  ("I'm-- I'm sorry, I don't understand what you mean.", 'you understand?'),
#  ('Damn it, my watch!', 'damn it, watch!'),
#  ('Article 2 Article 2(3) Act of Accession Article 2 Article 2(4) Article 3 Article 2(5) and (6)',
#   'article 3 Article 2 (5) and (6)'),
#  ("No, you're not gonna be suspended, Jules.",
#   "no, I'm not suspending you, Jules."),
#  ("I just don't wanna see you break up.",
#   "I just don't want you guys to break up."),
#  ('What you wanna do now?', 'you wanna do this on your own?'),
#  ("She told me that I was the most respectful man she's ever dated.",
#   'she told me I was the most polite man she ever dated.'),
#  ('Died because he wanted a woman enough to bring me here alone at night... in spite of the hound of the Baskervilles.',
#   'he died because he wanted a woman, enough to bring me here at night...... despite the troubles of Baskerville.'),
#  ('"Have a nice day."', '"good day."'),
#  ('Did I do something?', 'did I do something wrong?'),
#  ('Aside from the fact that he is gorgeous, charming and sings like an angel...',
#   'besides being beautiful, charming, and she can sing like an angel...'),
#  ("Yeah, they're jumping.", "they're jumping."),
#  ('"Don\'t you?" he repeated, but got no answer to his question.',
#   '"you don\'t want to?" He repeated, but there was no answer.'),
#  ('Jack stood up and took the conch.', 'Hawat stood.'),
#  ("I'm glad to hear you say that, Frank.", 'I hear you difficult.'),
#  ('This is alpha leader.', 'Alpha Leader here.'),
#  ('Article 2 regroups all the definitions of the terms used in the Directive.',
#   'article 2 contains all definitions of terms used in the directive.'),
#  ('Thanks for coming over tonight.', 'thank you for coming tonight.'),
#  ('"Pleasanter for you, I am afraid," murmured Hallward regretfully.',
#   '"sorry," I murmured.'),
#  ("Nothing to worry about, and I swear to God, I'll bin the thing myself.",
#   "there's nothing to worry about, and I swear to God I'll throw it out myself."),
#  ("You know we're on a mission from God, man.", 'you have a mission.'),
#  ('Mine was like, fish.', "mine's fish."),
#  ("It'd be nice to have lips.", 'it would be wonderful to have lips.'),
#  ('It is imperative that we put a freeze... ...on nuclear weapons of mass destruction.',
#   'it is imperative that we reduce...... the number of nuclear weapons of mass destruction.'),
#  ('Is your wife pretty?',
#   'and this deal is between you and your wife... or you and your wife?'),
#  ('A few days earlier I was attacked by his wife.',
#   'a few days earlier...... his wife attacked me.'),
#  ('Embalming is a fine art, Buzz.', 'fine, fine.'),
#  ('Not the short way, but the long way.', 'she was, but not long.'),
#  ("You don't recognize him at all?", "you don't really recognize him?"),
#  ('As Lardis examined him, he coughed and groaned, began to stir.',
#   'while Lardis examined him, he coughed, groaned and began to move.'),
#  ('Her what? £500, uncle, for the last novel, The Mysteries of Udolpho.',
#   'last one, for the last time.'),
#  ('Microsoft Profile Assistant stores your personal information.',
# ...
#  ('And you think the dead man was planning to go there, perhaps to meet someone?',
#   'and you think a dead man was planning to go there, meet someone there?'),
#  ('Garcia checkedwith the state police.', 'the state?'),
#  ('And then what will happen?', 'then what happens?'),
#  ('Now, I need some info.', 'I need some information.'),
#  ("We couldn't get a warrant.", "we didn't get a warrant."),
#  ("'If my husband doesn't have an alibi for this murder you say he committed, you take him to the police station!",
#   '"if my husband doesn\'t have an alibi for the murder you claim he committed, you will escort him to the police station!'),
#  ('"They\'re actually stealing them from themselves, looting the Russian army, but, and more important, they\'re buying them on the black market"',
#   '"they\'re basically stealing from themselves, filling the Russian army, but more importantly, they\'re buying them on the black market."'),
#  ('Apparently, he thinks you have something to contribute.',
#   'he seems to think you have something to contribute.'),
#  ('Like that pictureof John Lennon and Yoko 0no.', 'Lennon and Yoko Ono.'),
#  ('Leave it outside the door.', 'leave it behind the door.'),
#  ('The star in the east leads us home', 'in the east.'),
#  ('His religious shows play all over the midwest on the radio and over most of the country on cable TV and the indy stations.',
#   'and the voice on the radio.'),
#  ('Preview the message to be printed', 'preview message before printing'),
#  ("If I were you I'd get rid of this stuff quick.",
#   "if I were you, I'd get rid of it pretty quickly."),
#  ('Initial internal affairs inquiry with charles crews, detective, lapd.',
#   'the first questioning of an internal affairs officer conducted with Charles Crews, an LAPD detective.'),
#  ("Knowing you... it's something much more complex than that.",
#   "it's wonderfully complex."),
#  ('define a new sequence generator', 'defines a new sequencing generator'),
#  ("I'll have you there in 20 minutes.", 'I have $20.'),
#  ("Oh, well, if you're sorry, you know...",
#   "well, if you're sorry, then you do."),
#  ('SPECIFIC PRECAUTIONS FOR THE DISPOSAL OF UNUSED PRODUCT OR',
#   'special PRECAUTIONS FOR THE DISPOSAL OF UNUSED PRODUCTS'),
#  ('Hagen looked a little sad but not surprised.',
#   'Hagen looked saddened, but not surprised.'),
#  ('Because I am an angry person.', "because I'm a mad man."),
#  ('What is your name?”', 'what\'s your name? "'),
#  ('*IPARRAGUIRRE GUENECHEA, Ma Soledad (E.T.A. Activist) born 25.4.1961 in Escoriaza (Navarra), identity card No 16.255.819 23.',
#   '* IPARRAGUIRRE GUENECHEA, Ma Soledad (ETA activist), born 25.4.1961 in Escoriaz (Navarra), identity card No 16 255 819 23.'),
#  ('And we did kill something.', 'and we killed something.'),
#  ('“Slow,” he ordered softly, his gaze hooded as he licked his fingers with long, sensuous laps of his tongue.',
#   '"slowly," he said quietly, licking his fingers with long, sensual strokes of his tongue.'),
#  ('It just got worse.', 'it gets worse.'),
#  ("Some are useful, some aren't.", "some of us have money, and some don't."),
#  ('Oh, now. Good night.', 'good night.'),
#  ("Let me just get your... what's that ?",
#   'let me just give you your... what?'),
#  ('The chef apologizes for the wait.',
#   'the full bomb is the specialities of an Italian chef who cooked frequently for divine Lucian Pavarotti.'),
#  ('Mr. Quintana, you and your foundation are facing human smuggling charges.',
#   'Mr. Quintano, you and your foundation...... are facing charges of smuggling.'),
#  ("Nick, stay. - Nick, it's okay, buddy.", "Nick, it's okay, buddy."),
#  ('Come up out of the bunker.', 'get out of the bunker.'),
#  ('Any luck finding a reason why someone would want Franklin dead?',
#   "you were lucky for a reason why anyone would want Franklin's death?"),
#  ("No, I, um... ...it's not... it's not that uncommon.",
#   "no, I... it's not that unusual."),
#  ("You think I'm giving anything back to him?", "I'm giving it to you."),
#  ("You're a greedy woman, Sara.", "you're greedy, Sara."),
#  ('Within the tax field it is important to help these countries strengthen their administrative capacity to be able to cooperate in particular to fight cross-border tax frauds.',
#   'in the area of taxation, it is important to help these countries strengthen their administrative capacity to cooperate in particular in the fight against cross-border tax fraud.'),
#  ('No, not reaJJy.', 'no, not really.'),
#  ("It's Hyde 2612.", 'Hyde 2612.'),
#  ('Before... ...what happened to my sister.', '"it happened.'),
#  ('I told you never to come in my room again, you little freak.',
#   "you're my golden girl, I'll never lie to you."),
#  ("I'm telling the truth, Doc.", "I'm telling you."),
#  ('This alpha predator of yours, doctor... ...do you really think he has a chance?',
#   "this one of your alpha predators, doctor...... do you really think he's got a shot?"),
#  ("You're noton drugs, are you?", "you're not on drugs, are you?"),
#  ('Ok, we gonna find Clay.', 'okay, now we find Clay.'),
#  ("Dad, when I wanna talk to you - if I wanna talk to you - I'll call you.",
#   "I'll call you when I talk to her."),
#  ("I didn't see him behind me until it was too late.",
#   "I didn't see him before it was too late."),
#  ('This will be over in a few hours and we can go our own Ways.',
#   'in a couple of hours this will be over and we can all go our way.'),
#  ('Oh. We are both in the same boat here, James and I.',
#   "we're on the same boat now, James and I."),
#  ("Oh, right, you can't fly.", "oh, sure, you can't fly."),
#  ('Nothing. Only what I read in the papers.',
#   'just what I read in the papers.'),
#  ('That lasagna smells good.', 'the lasagna smells wonderful.'),
#  ('27 Article 1 of the contested directive provides for the addition to Article 26 of Directive 2003/54 of a paragraph 3 worded as follows:',
#   '14 According to Paragraph 65 of the Law:'),
#  ("But unless you give me something real... something or someone that proves you're a U.S. citizen... there's nothing I can do for you.",
#   "but if you don't give me something real to prove that you're a U.S. citizen, I can't do anything for you."),
#  ('General Howe applies his military strategy on the field with the discipline and precision of a science, but what I do... is closer to an art.',
#   'bring all the children To keep the order, and the discipline of Germany is... a civilized country.'),
#  ("I'm sorry, Dr. Bishop. I hope our little princess hasn't caused you too much trouble. No trouble at all.",
#   "I'm sorry, Dr. Bishop, I hope our little princess hasn't caused much trouble."),
#  ('Furthermore, as an exception, it must be given a strict interpretation.',
#   'in addition, it must be interpreted strictly as an exception.'),
#  ('On September 22, 2004,',
#   'on September 22, 2004, the Ztracenipremier was in the US.'),
#  ("He's not at the house?", "he's not home?"),
#  ("(second man) If you don't fly this thing, Ray, I swear to God, I'm gonna kill you.",
#   "I swear to God, Harold, I'm not gonna live like this anymore."),
#  ('Five thousand years of acid reflux will do that to you.',
#   'that will make you five thousand years of heartburn.'),
#  ('Jamie Fraser, how dare ye shed MacDonald blood without my approbation?',
#   "Jamie Fraser, how dare you shed McDonald's blood without my permission?"),
#  ("I've never seen her.",
#   "because I've never had a date with a deaf woman, I wanted to be ready."),
#  ("It's about Rose.", "it's not about the results, it's about the method."),
#  ("Who cares what they're into?", 'who cares what they like?'),
#  ('And you know nothing about the gramophone?',
#   "you don't know anything about a gramophone?"),
#  ('Which is why we are allowing the police onto our property, and which is why we will help them look.',
#   'the police know.'),
#  ("She's a woman.", "it's a woman!"),
#  ('No, no. N... um...', 'no, no.'),
#  ('But just trust me.', 'but you have to trust me.'),
#  ('Paul Eddington can take care of her.',
#   'Paul Eddington will take care of it.'),
#  ('The dealer takes three.', 'dealer wants three.'),
#  ("You're so worried about Hatsu you've lost your appetite, haven't you?",
#   "haven't we lost?"),
#  ('Cocoa ( 4 ) (fermented beans)', 'cocoa (4) (fermented berries)'),
#  ("I'm gonna need it.",
#   "I'm gonna lie to you, or I'm gonna have to shoot you."),
#  ('Please be seated.', 'sit down, please.'),
#  ("This isn't just a bank heist... ..it's a time-travel heist.",
#   "it's your bank."),
#  ('There it is.', 'there she is.'),
#  ('Oh, the hair is actually your hair.', "that's your real hair."),
#  ('Should have been born earlier, Nix.',
#   'we should have been born before, Nix.'),
#  ("What things don't we know?", "what do we don't know?"),
#  ('Mrs.Rogerson,according to your C.T., You have severe internal bleeding.',
#   'Mrs. Rogerson, according to your C.T., you have strong internal bleeding.'),
#  ('Because I know you.', 'you know, I know, and you hate that I know.'),
#  ('So, look for your first clue under the sea.', 'okay, clue.'),
#  ('So, did you get them?', 'so you got them?'),
#  ('I need to, uh... excuse me.', 'excuse me.'),
#  ('It was quite a battle, but we have a winner.', "it's quite."),
#  ('Morning, my darling.', 'hello, my dear.'),
#  ('In the last few hours. Selby and Jana Vickers, 33 and 31 years old,',
#   'Selby and John Vickers, 33 and 31 years old.'),
#  ("Council Decision 2014/512/CFSP of 31 July 2014 concerning restrictive measures in view of Russia's actions destabilising the situation in Ukraine ( OJ L 229, 31.7.2014, p. 13 ).",
#   "(3) Council Decision 2014 / 512 / CFSP of 31 July 2014 concerning restrictive measures in respect of Russia's actions in Ukraine (OJ L 229, 31.7.2014, p. 13)."),
#  ("You don't know what I'm wearing underneath this Santa outfit.",
#   "you don't know what I'm wearing under Santa's suit!"),
#  ('...a jade dartthat can kill an immortal.',
#   'a jade dart that will kill Immortal.'),
#  ('Cash Journals', 'cash journal'),
#  ('Any operating aid may then be granted only for plant depreciation.',
#   'any operating aid can then be granted only for the depreciation of the production plant.'),
#  ("Tomorrow, perhaps, or maybe some time next year, you know, because I'm honor-bound.",
#   "tomorrow, maybe, or maybe sometime next year, you know, because it's a matter of honor."),
#  ('I need to know if somebody pawned a camera here in the past 24 hours.',
#   'I need to know if anyone has stopped the camera in the last 24 hours.'),
#  ("But we couldn't find the mini-dome anywhere.",
#   'we find the golfer, we find the killer.'),
#  ('The man was more than twice his age-was he just old?',
#   'Curdin was more than twice his age-so he had aged?'),
#  ("(b) Flexible working hours may be agreed by the Director in accordance with staff members' personal circumstances or the constraints of their particular work.",
#   '(B) The Director may approve flexible working hours according to the personal circumstances of the staff or, according to the specific requirements set out in their work.'),
#  ('Adverse reactions with at least 2% difference over placebo are marked in italics.',
#   'side effects with at least 2% difference versus placebo are marked with italics.'),
#  ('"Wasn\'t Filitov the first witness against him?" asked the head of the Second Directorate.',
#   '"didn\'t Filitov go against him as a crown witness?" The Chief of the Second Administration asked.'),
#  ('For these reasons the strategy must now enter a phase of fruition in which all the opportunities of the 2004 strategy are harvested.',
#   'for this reason, the strategy must now enter a decisive phase and take advantage of all the opportunities of the 2004 strategy.'),
#  ("It's about Rose.", "it's not about you I'm worried about."),
#  ("I don't wanna hear about... your interesting moment with Sarah, Pete.",
#   "I don't want to hear about your interesting experiences with Sarah, Pete."),
#  ("And I'm still doing it.", 'and I still do.'),
#  ("The President did say it was directed at Earth's oceans.",
#   'it was directed at the man.'),
#  ('Removed manual numbering', 'deleted manual numbering.'),
#  ('I will have to have it cleaned.', "I'll have to have him cleaned up."),
#  ('Well, he did break my nose.', 'he broke my nose.'),
#  ('It means I have a human thing called an adrenalin gland.',
#   'we humans have something called an adrenaline gland.'),
#  ('I may even avoid a reprimand for my carelessness, though the Citizen knows I know I deserve one.',
#   'I deserve to know, Kenny.'),
#  ('Jack slipped me his watch.', 'I slipped.'),
#  ('All right, Higbe, shake it off, there.', 'all right, shake it up, Higbe.'),
#  ('The Blur, The Flash, the man in the red suit...',
#   'streak, The Flash, the man in the red suit...'),
#  ('Opioid agonist ceiling effects were observed during clinical pharmacology studies in opioid- dependent persons.',
#   'the effect of the ceiling opioid agonists has been observed during clinical pharmacology studies in humans dependent on opioids.'),
#  ("Hey, how ya doin'?", "hey, how's it going?"),
#  ('This is Eagle 1.', 'this is Eagle One.'),
#  ('Um... cockroaches.', 'cockroaches.'),
#  ('A friend gave them to me.',
#   'you gave up everything to be with me to be a forest bandit, and then you told me something I should have taken to my heart.'),
#  ('Now, you know what happens when you talk to Erik Bloodaxe as if he were a thrall.',
#   'now you know what happens when you talk to Eric Bloodaxe as a slave.'),
#  ("Officer Acker's the only connection we have left.",
#   'we have a connection.'),
#  ('A monster.', 'monster!'),
#  ('"Let go of me, Thomas."', '"get away from me, Thomas."'),
#  ("Who says they're still your guys?", "who said they're your men?"),
#  ("PPAs served to guarantee the power plants' viability.",
#   'the PPAs served as a guarantee of the viability of the power plants.'),
#  ('"Run, John Carter!" shouted Han Du, but I did not run.',
#   '"everybody!" I shouted.'),
#  ('Hello, Miss Lubin. - Oh, hello there.', 'hello, hello, hello Studley.'),
#  ("He jumped as if she'd stung him, which amused the hell out of her.",
#   'she jumped out of the water as if fired from the cannon.'),
#  ("I can't remove the barrier that has you trapped until I have my hand around this throat.",
#   "I can't remove the barrier that imprisons you until I have my hands on his neck."),
#  ('Displays the contents of a text file or files.',
#   'displays the contents of the text file.'),
#  ("'Cause if there was, I can breathe again.",
#   'because if it is, I can breathe again.'),
#  ('The lack of response from importers and users suggests that the measures currently in force have not had a significant impact on their business.',
#   'an inadequate response from importers and users indicates that the current measures in force do not have a significant impact on their trade.'),
#  ("It's about Rose.", "it's not about Carmen, it's about you."),
#  ('She kissed your neck or your lips?',
#   'was it up to your neck or on your lips?'),
#  ('After reconstitution Chemical and physical in-use stability has been demonstrated for 24 hours at 2°C - 8ºC.',
#   'in 24 hours.'),
#  ('I know this.', 'I know him.'),
#  ("If you scared, that means you don't got it.", 'it means...'),
#  ('The tunnel or the roof?', 'the tunnel!'),
#  ("I'm gonna take Tig.", "I'll take Tig."),
#  ('I was with him the entire time, all right?',
#   "I've been with him this whole time, okay?"),
#  ('Okay, Francis. cigarette.', 'sure, Francis.... cigarette.'),
#  ("Now,this guy... Eli... Mike, I think he's had some training.",
#   "this guy... Eli... I think he's got some training."),
#  ('Your girlfriend left cards all over the club, remember?',
#   'your friend left his card at the club, remember?'),
#  ('Are you sure about this, sir? No.', 'are you sure about this, sir?'),
#  ("It's written on a Lyxian scale.", "it's not written."),
#  ('"I do," Ardmore said dryly.', '"you know I have," Ardmore said dryly.'),
#  ('Never him.', 'his never.'),
#  ("No. Those aren't her eyes.", "no, it's not her eyes."),
#  ('Marcus, trust no one else.', "Marcus.... don't trust anyone else."),
#  ('It should be clear ...', 'it should be clear.'),
#  ('Does it have to be done?', 'does it have to be?')]

# %% [markdown]
# ## Preprocessing

# %%
import nltk
import re

STOP = set(nltk.corpus.stopwords.words("english"))

class Sentence:
    
    def __init__(self, sentence):
        self.raw = sentence
        text = sentence.replace("‘", "'").replace("’", "'").lower()
        text = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", text)
        text = re.sub(r"\'s", " 's ", text)
        text = re.sub(r"\'ve", " have ", text)
        text = re.sub(r"n't", " not ", text)
        text = re.sub(r"i'm", "i am ", text)
        text = re.sub(r"\'re", " are ", text)
        text = re.sub(r"\'d", " would ", text)
        text = re.sub(r"\'ll", " will ", text)
        text = re.sub(r",", " , ", text)
        text = re.sub(r"\.\.\.", " ", text)
        text = re.sub(r"\.", " . ", text)
        text = re.sub(r"!", " ! ", text)
        text = re.sub(r"\-", " - ", text)
        text = re.sub(r":", " : ", text)
        self.tokens = [t for t in nltk.word_tokenize(text)]
        self.tokens_without_stop = [t for t in self.tokens if t not in STOP]

# %% [markdown]
# ## Generate Negative Example

# %%
import random
from nltk.corpus import wordnet 
inverse = ["are", "is", "am", "will", "would", "can"]

def to_negative(tokens):
    for i, token in enumerate(tokens):
        if token in inverse and i != len(tokens)-1:
            if tokens[i+1] == "not" or tokens[i+1] == "n't":
                return tokens[:i+1] + tokens[i+2:]
            else:
                return tokens[:i+1] + ["not"] + tokens[i+1:]
        for syn in wordnet.synsets(token): 
            for l in syn.lemmas(): 
                if l.antonyms(): 
                    tokens[i] = random.choice(l.antonyms()).name()
                    return tokens
    return []

def generate_n_negative(train, n):
    res = []
    for s1, s2 in train:
        sen1 = Sentence(s1)
        sen2 = Sentence(s2)
        if to_negative(sen1.tokens):
            res.append((' '.join(sen1.tokens), ' '.join(sen2.tokens)))
            n -= 1
        elif to_negative(sen2.tokens):
            res.append((' '.join(sen2.tokens), ' '.join(sen1.tokens)))
            n -= 1
        if not n:
            return res

# %%
NUM_POSITIVE = 20000
NUM_NEGATIVE = NUM_POSITIVE // 2
NUM_DATA = 2 * NUM_POSITIVE

X = X_train[:NUM_POSITIVE] \
    + list(zip([s1 for s1, _ in X_train[NUM_POSITIVE:NUM_POSITIVE+NUM_NEGATIVE]], [s2 for _, s2 in X_train[NUM_POSITIVE+NUM_NEGATIVE:NUM_POSITIVE+2*NUM_NEGATIVE]])) \
    + generate_n_negative(X_train[NUM_POSITIVE+2*NUM_NEGATIVE:], NUM_NEGATIVE)
y = [1 for _ in range(NUM_POSITIVE)] + [0 for _ in range(NUM_POSITIVE)]

# %% [markdown]
# ## Pre-trained Word-Embeddings

# %%
import gensim

from gensim.models import Word2Vec
from gensim.scripts.glove2word2vec import glove2word2vec
import gensim.downloader as api

# PATH_TO_WORD2VEC = os.path.expanduser("data/word2vec/GoogleNews-vectors-negative300.bin")
PATH_TO_GLOVE = os.path.expanduser("../glove.840B.300d.txt")

word2vec = api.load('word2vec-google-news-300')
tmp_file = "glove.840B.300d.w2v.txt"
# glove2word2vec(W2V_PATH, tmp_file)
glove = gensim.models.KeyedVectors.load_word2vec_format(tmp_file)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1209 04:17:42.074544 4489231808 utils_any2vec.py:157] duplicate word '����������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������' in word2vec file, ignoring all but first
# WARNING: Logging before flag parsing goes to stderr.
# W1209 04:17:42.074544 4489231808 utils_any2vec.py:157] duplicate word '����������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������' in word2vec file, ignoring all but first

# %%
import csv

PATH_TO_FREQUENCIES_FILE = "data/sentence_similarity/frequencies.tsv"
PATH_TO_DOC_FREQUENCIES_FILE = "data/sentence_similarity/doc_frequencies.tsv"

def read_tsv(f):
    frequencies = {}
    with open(f) as tsv:
        tsv_reader = csv.reader(tsv, delimiter="\t")
        for row in tsv_reader: 
            frequencies[row[0]] = int(row[1])
        
    return frequencies
        
frequencies = read_tsv(PATH_TO_FREQUENCIES_FILE)
doc_frequencies = read_tsv(PATH_TO_DOC_FREQUENCIES_FILE)
doc_frequencies["NUM_DOCS"] = 1288431

# %% [markdown]
# ## Sentence-Embedding Methods

# %%
from sklearn import svm

def run_experiment(X, y, embed_func, model=None, kernel=None, doc_freqs=None, freqs=None, gamma='auto'): 
     
    X_embed_train, y_embed_train = embed_func(X, y)
    
    X_embed_dev, y_embed_dev = embed_func(X_dev, y_dev)
    X_embed_devtest, y_embed_devtest = embed_func(X_devtest, y_devtest)
    
    gammas = [0.1, 0.01, 0.001, 0.0001]
    for g in gammas:
        classifier = svm.SVC(kernel=kernel, gamma=g)
        classifier.fit(X_embed_train, y_embed_train)
        print((classifier.score(X_embed_dev, y_embed_dev), classifier.score(X_embed_devtest, y_embed_devtest)))
    
#     return classifier.score(X_embed_dev, y_embed_dev), classifier.score(X_embed_devtest, y_embed_devtest)

# %% [markdown]
# ### Baseline

# %%
from collections import Counter
import math
from sklearn import svm, metrics

def get_avg_embeddings(X, y, model=None, doc_freqs=None):
    if doc_freqs is not None:
        N = doc_freqs["NUM_DOCS"]
    
    X_embed, y_embed = [], []
    for i, (s1, s2) in enumerate(X):
        sent1 = Sentence(s1)
        sent2 = Sentence(s2)
    
        tokens1 = [token for token in sent1.tokens if token in model]
        tokens2 = [token for token in sent2.tokens if token in model]
        
        if len(tokens1) == 0 or len(tokens2) == 0:
            continue
        
        tokfreqs1 = Counter(tokens1)
        tokfreqs2 = Counter(tokens2)
        
        weights1 = [tokfreqs1[token] * math.log(N/(doc_freqs.get(token, 0)+1)) 
                    for token in tokfreqs1] if doc_freqs else None
        weights2 = [tokfreqs2[token] * math.log(N/(doc_freqs.get(token, 0)+1)) 
                    for token in tokfreqs2] if doc_freqs else None
                
        embedding1 = np.average([model[token] for token in tokfreqs1], axis=0, weights=weights1).reshape(1, -1)
        embedding2 = np.average([model[token] for token in tokfreqs2], axis=0, weights=weights2).reshape(1, -1)

        X_embed.append(np.concatenate((embedding1, embedding2), axis=1)[0])
        y_embed.append(y[i])
        
    return X_embed, y_embed

# %%
X_embed_train, y_embed_train = get_avg_embeddings(X, y, model=word2vec, doc_freqs=doc_frequencies)
    
X_embed_dev, y_embed_dev = get_avg_embeddings(X_dev, y_dev, model=word2vec, doc_freqs=doc_frequencies)
X_embed_devtest, y_embed_devtest = get_avg_embeddings(X_devtest, y_devtest, model=word2vec, doc_freqs=doc_frequencies)

gammas = [0.1, 0.01, 0.001, 0.0001]
for g in gammas:
    classifier = svm.SVC(kernel='rbf', gamma=g)
    classifier.fit(X_embed_train, y_embed_train)
    print((classifier.score(X_embed_dev, y_embed_dev), classifier.score(X_embed_devtest, y_embed_devtest)))
# Out:
# (0.6842105263157895, 0.681592039800995)
# (0.6842105263157895, 0.681592039800995)
# (0.583843329253366, 0.5746268656716418)
# (0.583843329253366, 0.5746268656716418)
# (0.587515299877601, 0.599502487562189)
# (0.587515299877601, 0.599502487562189)
# (0.3684210526315789, 0.3681592039800995)
# (0.3684210526315789, 0.3681592039800995)

# %% [markdown]
# ### Smooth Inverse Frequency

# %%
from sklearn.decomposition import TruncatedSVD

def remove_first_principal_component(X):   
    svd = TruncatedSVD(n_components=1, n_iter=7, random_state=0)
    svd.fit(X)
    pc = svd.components_
    XX = X - X.dot(pc.transpose()) * pc
    return XX


import copy

def get_sif_embeddings(X, y, model=None, freqs={}, use_stoplist=False, a=0.001):
    total_freq = sum(freqs.values())
    
    embeddings = []
    y_embed = copy.deepcopy(y)
    
    # SIF requires us to first collect all sentence embeddings and then perform 
    # common component analysis.
    for i, (s1, s2) in enumerate(X): 
        
        sent1 = Sentence(s1)
        sent2 = Sentence(s2)
    
        tokens1 = [token for token in sent1.tokens if token in model]
        tokens2 = [token for token in sent2.tokens if token in model]
        
        if len(tokens1) == 0 or len(tokens2) == 0:
            del y_embed[i]
            continue
        
        weights1 = [a/(a+freqs.get(token,0)/total_freq) for token in tokens1]
        weights2 = [a/(a+freqs.get(token,0)/total_freq) for token in tokens2]
        
        embedding1 = np.average([model[token] for token in tokens1], axis=0, weights=weights1)
        embedding2 = np.average([model[token] for token in tokens2], axis=0, weights=weights2)
        
        embeddings.append(embedding1)
        embeddings.append(embedding2)
    
    embeddings = remove_first_principal_component(np.array(embeddings))
    
    X_embed = [np.concatenate((embeddings[idx*2].reshape(1, -1), 
                              embeddings[idx*2+1].reshape(1, -1))[0])
            for idx in range(int(len(embeddings)/2))]
    
    return X_embed, y_embed

# %%
X_embed_train, y_embed_train = get_sif_embeddings(X, y, model=word2vec, freqs=frequencies)
    
X_embed_dev, y_embed_dev = get_sif_embeddings(X_dev, y_dev, model=word2vec, freqs=frequencies)
X_embed_devtest, y_embed_devtest = get_sif_embeddings(X_devtest, y_devtest, model=word2vec, freqs=frequencies)

gammas = [0.1, 0.01, 0.001, 0.0001]
for g in gammas:
    classifier = svm.SVC(kernel='rbf', gamma=g)
    classifier.fit(X_embed_train, y_embed_train)
    print((classifier.score(X_embed_dev, y_embed_dev), classifier.score(X_embed_devtest, y_embed_devtest)))
# Out:
# (0.5324357405140759, 0.5783582089552238)
# (0.5324357405140759, 0.5783582089552238)
# (0.5348837209302325, 0.5360696517412935)
# (0.5348837209302325, 0.5360696517412935)
# (0.572827417380661, 0.5621890547263682)
# (0.572827417380661, 0.5621890547263682)
# (0.3684210526315789, 0.3681592039800995)
# (0.3684210526315789, 0.3681592039800995)

# %% [markdown]
# ### InferSent

# %%
import torch
from models import InferSent

model_version = 1
MODEL_PATH = "../InferSent-master/encoder/infersent%s.pkl" % model_version
params_model = {'bsize': 64, 'word_emb_dim': 300, 'enc_lstm_dim': 2048,
                'pool_type': 'max', 'dpout_model': 0.0, 'version': model_version}
infersent = InferSent(params_model)
infersent.load_state_dict(torch.load(MODEL_PATH))
W2V_PATH = '../glove.840B.300d.txt' if model_version == 1 else 'fastText/crawl-300d-2M.vec'
infersent.set_w2v_path(W2V_PATH)

# %%
def get_inf_embeddings(X, y):
    
    raw_sentences1 = [s1 for s1, _ in X]
    raw_sentences2 = [s2 for _, s2 in X]
    
    infersent.build_vocab(raw_sentences1 + raw_sentences2, tokenize=True)
    embeddings1 = infersent.encode(raw_sentences1, tokenize=True)
    embeddings2 = infersent.encode(raw_sentences2, tokenize=True)
    
    X_embed = []
    for (emb1, emb2) in zip(embeddings1, embeddings2): 
        X_embed.append(np.concatenate((emb1, emb2), axis=0))
        
    return X_embed, y

# %%
X_embed_train, y_embed_train = get_inf_embeddings(X, y)
    
X_embed_dev, y_embed_dev = get_inf_embeddings(X_dev, y_dev)
X_embed_devtest, y_embed_devtest = get_inf_embeddings(X_devtest, y_devtest)

gammas = [0.1, 0.01, 0.001, 0.0001]
for g in gammas:
    classifier = svm.SVC(kernel='rbf', gamma=g)
    classifier.fit(X_embed_train, y_embed_train)
    print((classifier.score(X_embed_dev, y_embed_dev), classifier.score(X_embed_devtest, y_embed_devtest)))
# Out:
# Found 38715(/44244) words with w2v vectors
# Vocab size : 38715
# Found 38715(/44244) words with w2v vectors
# Vocab size : 38715
# Found 2908(/3000) words with w2v vectors
# Vocab size : 2908
# Found 2908(/3000) words with w2v vectors
# Vocab size : 2908
# Found 2910(/3005) words with w2v vectors
# Vocab size : 2910
# Found 2910(/3005) words with w2v vectors
# Vocab size : 2910
# (0.7359413202933985, 0.7453416149068323)
# (0.7359413202933985, 0.7453416149068323)
# (0.7029339853300733, 0.7080745341614907)
# (0.7029339853300733, 0.7080745341614907)
